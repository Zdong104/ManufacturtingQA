# %%
import os
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
from llama_index.llms.openai import OpenAI
from llama_index.core import Settings
from dotenv import load_dotenv

# Load the environment variables from the specified .env file
dotenv_path = '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/.env'
load_dotenv(dotenv_path)

# Load the OpenAI API key from the environment variable
api_key = os.getenv('GRAPHRAG_API_KEY')
assert api_key is not None, "OpenAI API key not found in environment variables."


documents = SimpleDirectoryReader("/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input").load_data()
print(documents)
print(documents[0].text)
# Out:
# [Document(id_='ab6850c6-e271-4a35-8e31-ce801e67df70', embedding=None, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Introduction \nand Overview of \nManufacturing \n \n \n \n \nChapter Contents \n1.1 What Is Manufacturing? \n1.1.1 Manufacturing Defined \n1.1.2 Manufacturing Industries and \nProducts \n1.1.3 Manufacturing Capability \n1.2 Materials in Manufacturing \n1.2.1 Metals \n1.2.2 Ceramics \n1.2.3 Polymers \n1.2.4 Composites \n1.3 Manufacturing Processes \n1.3.1 Processing Operations \n1.3.2 Assembly Operations \n1.3.3 Production Machines and Tooling \n1.4 Production Systems \n1.4.1 Production Facilities \n1.4.2 Manufacturing Support Systems \n1.5 Manufacturing Economics \n1.5.1 Production Cycle Time Analysis \n1.5.2 Manufacturing Cost Models \n1.6 Recent Developments in Manufacturing \nMaking things has been an essential activity of human \ncivilizations since before recorded history. Today, the \nterm manufacturing is used for this activity. For techno- \nlogical and economic reasons, manufacturing is impor- \ntant to the welfare of the United States and most other \ndeveloped and developing nations. Technology can be \ndefined as the application of science to provide society \nand its members with those things that are needed or \ndesired. Technology affects our daily lives, directly and \nindirectly, in many ways. Consider the list of products in \nTable 1.1. They represent various technologies that help our \nsociety and its members to live better. What do all these \nproducts have in common? They are all manufac- tured. \nThese technological wonders would not be avail- able to \nour society if they could not be manufactured. \nManufacturing is the critical factor that makes technol- \nogy possible. \nEconomically, manufacturing is an important means \nby which a nation creates material wealth. In the Unit- \ned States, the manufacturing industries account for \nonly about 12% of gross domestic product (GDP). A \ncountry’s natural resources, such as agricultural lands, \nmineral deposits, and oil reserves, also create wealth. \nIn the U.S., agriculture, mining, and similar industries \naccount for less than 5% of GDP (agriculture alone is \nonly about 1%). Construction and public utilities make \nup around 5%. The rest is service industries, which in- \nclude retail, transportation, banking, communication, \neducation, and government. The service sector ac- \ncounts for more than 75% of U.S. GDP. Government \n(federal, state, and local) accounts for more of GDP \nthan the manufacturing sector; however, government \nservices do not create wealth. In the modern global \neconomy, a nation must have a strong manufacturing \nbase (or it must have significant natural resources) if it \nis to provide a strong economy and a high standard of \nliving for its people. \n1 \n1 \nSection 1.1/What Is Manufacturing? \n2 \n \n \nTABLE • 1.1 Products representing various technologies, most of which affect nearly all of us. \n \nAthletic shoes \nE-book reader \nOne-piece molded plastic patio chair \nAutomatic teller machine \nFax machine \nOptical scanner \nAutomatic dishwasher \nHand-held electronic calculator \nPersonal computer (PC) \nBallpoint pen \nHigh density PC diskette \nPhotocopying machine \nCamcorder \nHome security system \nPull-tab beverage cans \nCell phone \nHybrid gas-electric automobile \nQuartz crystal wrist watch \nCompact disc (CD) \nIndustrial robot \nSelf-propelled mulching lawnmower \nCompact disc player \nInk-jet color printer ...
# Introduction
# and Overview of
# Manufacturing
#
#
#
#
# Chapter Contents
# 1.1 What Is Manufacturing?
# 1.1.1 Manufacturing Defined
# 1.1.2 Manufacturing Industries and
# Products
# 1.1.3 Manufacturing Capability
# 1.2 Materials in Manufacturing
# 1.2.1 Metals
# 1.2.2 Ceramics
# 1.2.3 Polymers
# 1.2.4 Composites
# 1.3 Manufacturing Processes
# 1.3.1 Processing Operations
# 1.3.2 Assembly Operations
# 1.3.3 Production Machines and Tooling
# 1.4 Production Systems
# 1.4.1 Production Facilities
# 1.4.2 Manufacturing Support Systems
# 1.5 Manufacturing Economics
# 1.5.1 Production Cycle Time Analysis
# 1.5.2 Manufacturing Cost Models
# 1.6 Recent Developments in Manufacturing
# Making things has been an essential activity of human
# civilizations since before recorded history. Today, the
# term manufacturing is used for this activity. For techno-
# logical and economic reasons, manufacturing is impor-
# tant to the welfare of the United States and most other
# developed and developing nations. Technology can be
# defined as the application of science to provide society
# and its members with those things that are needed or
# desired. Technology affects our daily lives, directly and
# indirectly, in many ways. Consider the list of products in
# Table 1.1. They represent various technologies that help our
# society and its members to live better. What do all these
# products have in common? They are all manufac- tured.
# These technological wonders would not be avail- able to
# our society if they could not be manufactured.
# Manufacturing is the critical factor that makes technol-
# ogy possible.
# Economically, manufacturing is an important means
# by which a nation creates material wealth. In the Unit-
# ed States, the manufacturing industries account for
# only about 12% of gross domestic product (GDP). A
# country’s natural resources, such as agricultural lands,
# mineral deposits, and oil reserves, also create wealth.
# In the U.S., agriculture, mining, and similar industries
# account for less than 5% of GDP (agriculture alone is
# only about 1%). Construction and public utilities make
# up around 5%. The rest is service industries, which in-
# clude retail, transportation, banking, communication,
# education, and government. The service sector ac-
# counts for more than 75% of U.S. GDP. Government
# (federal, state, and local) accounts for more of GDP
# than the manufacturing sector; however, government
# services do not create wealth. In the modern global
# economy, a nation must have a strong manufacturing
# base (or it must have significant natural resources) if it
# is to provide a strong economy and a high standard of
# living for its people.
# 1
# 1
# Section 1.1/What Is Manufacturing?
# 2
#
#
# TABLE • 1.1 Products representing various technologies, most of which affect nearly all of us.
#
# Athletic shoes
# E-book reader
# One-piece molded plastic patio chair
# Automatic teller machine
# Fax machine
# Optical scanner
# Automatic dishwasher
# Hand-held electronic calculator
# Personal computer (PC)
# Ballpoint pen
# High density PC diskette
# Photocopying machine
# Camcorder
# Home security system
# Pull-tab beverage cans
# Cell phone
# Hybrid gas-electric automobile
# Quartz crystal wrist watch
# Compact disc (CD)
# Industrial robot
# Self-propelled mulching lawnmower
# Compact disc player
# Ink-jet color printer
# Smart phone
# Compact fluorescent light bulb
# LCD and Plasma TVs
# Supersonic aircraft
# Contact lenses
# Magnetic resonance imaging (MRI)
# Tablet computer
# Digital camera
# machine for medical diagnosis
# Tennis racket of composite materials
# Digital video disc (DVD)
# Medicines
# Video games
# Digital video disc player
# Microwave oven
# Washing machine and dryer
#
#
# This opening chapter considers some general topics about manufacturing. What is
# manufacturing? How is it organized in industry? What are the materials, processes,
# and systems by which it is accomplished?
#
# What Is Manufacturing?
# The word manufacture is derived from two Latin words, manus (hand) and factus
# (make); the combination means made by hand. The English word manufacture is
# several centuries old, and “made by hand” accurately described the manual methods
# used when the word was first coined.1 Most modern manufacturing is accomplished
# by automated and computer-controlled machinery (Historical Note 1.1).
#
#
#
# 1As a noun, the word manufacture first appeared in English around 1567 A.D. As a verb, it first appeared
# around 1683 A.D.
# .
#
# The history of manufacturing can be separated into  weapons, scrolls, pottery and glassware, and other
# two subjects: (1) the discovery and invention of mate-  products of the time, but the procedures were largely
# rials and processes to make things, and (2) the devel-  based on handicraft.
# opment of the systems of production. The materials   The systems aspects of manufacturing are examined
# and processes to make things predate the systems  here, and the materials and processes are discussed in
# by several millennia. Some of the processes—casting, Historical Note 1.2. Systems of manufacturing refer
# hammering (forging), and grinding—date back 6000 to the ways of organizing people and equipment so years
# or more. The early fabrication of implements and that production can be performed more efficiently. weapons
# was accomplished more as crafts and trades
# Several historical events and discoveries stand out than
# manufacturing as it is known today. The ancient as having had a major impact on the development of Romans
# had what might be called factories to produce  modern manufacturing systems.
# Section 1.1/What Is Manufacturing?
# 3
#
#
#
# Certainly one significant discovery was the principle
# of division of labor—dividing the total work into tasks
# and having individual workers each become a special-
# ist at performing only one task. This principle had been
# practiced for centuries, but the economist Adam Smith
# (1723–1790) is credited with first explaining its eco-
# nomic significance in The Wealth of Nations.
# The Industrial Revolution (circa 1760–1830) had
# a major impact on production in several ways. It
# marked the change from an economy based on agri-
# culture and handicraft to one based on industry and
# manufacturing. The change began in England, where a
# series of machines were invented and steam power
# replaced water, wind, and animal power. These ad-
# vances gave British industry significant advantages
# over other nations, and England attempted to restrict
# export of the new technologies. However, the revo-
# lution eventually spread to other European countries
# and the United States. Several inventions of the Indus-
# trial Revolution greatly contributed to the development
# of manufacturing: (1) Watt’s steam engine—a new
# power-generating technology for industry; (2) machine
# tools, starting with John Wilkinson’s boring machine
# around 1775 (Historical Note 21.1); (3) the spinning
# jenny, power loom, and other machinery for the tex-
# tile industry that permitted significant increases in
# productivity; and (4) the factory system—a new way
# of organizing large numbers of production workers
# based on division of labor.
# While England was leading the industrial revolu-
# tion, an important concept was being introduced in the
# United States: interchangeable parts manufacture.
# Much credit for this concept is given to Eli Whitney
# (1765–1825), although its importance had been rec-
# ognized by others [10]. In 1797, Whitney negotiated
# a contract to produce 10,000 muskets for the U.S.
# government. The traditional way of making guns at the
# time was to custom-fabricate each part for a par- ticular
# gun and then hand-fit the parts together by fil- ing.
# Each musket was unique, and the time to make it was
# considerable. Whitney believed that the com- ponents
# could be made accurately enough to permit parts
# assembly without fitting. After several years of
# development in his Connecticut factory, he traveled to
# Washington in 1801 to demonstrate the principle.
# He laid out components for 10 muskets before gov-
# ernment officials, including Thomas Jefferson, and
# proceeded to select parts randomly to assemble the
# guns. No special filing or fitting was required, and
# all of the guns worked perfectly. The secret be- hind his
# achievement was the collection of special machines,
# fixtures, and gages that he had developed in
# his
# factory. Interchangeable parts manufacture
# required many years of development before becom-
# ing a practical reality, but it revolutionized methods of
# manufacturing. It is a prerequisite for mass produc-
# tion. Because its origins were in the United States,
# interchangeable parts production came to be known as
# the American System of manufacture.
# The mid- and late 1800s witnessed the expan- sion
# of railroads, steam-powered ships, and other machines
# that created a growing need for iron and steel. New
# steel production methods were devel- oped to meet
# this demand (Historical Note 6.1). Also during this
# period, several consumer products were developed,
# including
# the
# sewing
# machine,
# bicycle,
# and
# automobile. To meet the mass demand for these
# products, more efficient production methods were
# required. Some historians identify developments dur-
# ing this period as the Second Industrial Revolution,
# characterized in terms of its effects on manufacturing
# systems by (1) mass production, (2) scientific manage-
# ment movement, (3) assembly lines, and (4) electrifi-
# cation of factories.
# In the late 1800s, the scientific management
# movement was developing in the United States in
# response to the need to plan and control the activi- ties
# of growing numbers of production workers. The
# movement’s leaders included Frederick W. Taylor
# (1856–1915), Frank Gilbreth (1868–1924), and his wife
# Lillian (1878–1972). Scientific management included
# several features [3]: (1) motion study, aimed at find-
# ing the best method to perform a given task; (2) time
# study, to establish work standards for a job; (3) exten-
# sive use of standards in industry; (4) the piece rate
# system and similar labor incentive plans; and (5) use
# of data collection, record keeping, and cost account-
# ing in factory operations.
# Henry Ford (1863–1947) introduced the assembly
# line in 1913 at his Highland Park, Michigan plant. The
# assembly line made possible the mass production of
# complex consumer products. Use of assembly line
# methods permitted Ford to sell a Model T automobile
# for as little as $500, thus making ownership of cars
# feasible for a large segment of the U.S. population.
# In 1881, the first electric power generating station
# had been built in New York City, and soon electric mo-
# tors were being used as a power source to operate fac-
# tory machinery. This was a far more convenient power
# delivery system than steam engines, which required
# overhead belts to distribute power to the machines. By
# 1920, electricity had overtaken steam as the principal
# power source in U.S. factories. The twentieth century
# was a time of more technological advances than in all
# other centuries combined. Many of these develop-
# ments resulted in the automation of manufacturing.
# Section 1.1/What Is Manufacturing?
# 4
#
#
#
#
# Scrap and
# waste
# Manufacturing
# process
#
#
#
#
#
# Starting
# material
# Processed
# part
# $
#
# $$$
#
#
#
#
# Starting
# material
# Material in
# processing
# Processed
# part
#
# (a)
# (b)
#
# FIGURE 1.1  Two ways to define manufacturing: (a) as a technical process, and (b) as an economic process.
#
#
# 1.1.1 MANUFACTURING DEFINED
#
# As a field of study in the modern context, manufacturing can be defined two ways,
# one technologic, and the other economic. Technologically, manufacturing is the ap-
# plication of physical and chemical processes to alter the geometry, properties, and/
# or appearance of a given starting material to make parts or products; manufacturing
# also includes assembly of multiple parts to make products. The processes to accom-
# plish manufacturing involve a combination of machinery, tools, power, and labor, as
# depicted in Figure 1.1(a). Manufacturing is almost always carried out as a sequence
# of operations. Each operation brings the material closer to the desired final state.
# Economically, manufacturing is the transformation of materials into items of
# greater value by means of one or more processing and/or assembly operations, as
# depicted in Figure 1.1(b). The key point is that manufacturing adds value to the
# material by changing its shape or properties, or by combining it with other materials
# that have been similarly altered. The material has been made more valuable through
# the manufacturing operations performed on it. When iron ore is converted into steel, value
# is added. When sand is transformed into glass, value is added. When petroleum is
# refined into plastic, value is added. And when plastic is molded into the complex
# geometry of a patio chair, it is made even more valuable.
# Figure 1.2 shows a product on the left and the starting workpiece from which the
# circular frame of the product was produced on the right. The starting workpiece is
#
#
#
#
#
#
#
# FIGURE 1.2 A mechanical
# heart value on the left and the
# titanium workpiece from which
# the frame is machined on the
# right. (Courtesy of George E.
# Kane Manufacturing Technology
# Laboratory, Lehigh University.)
# Machinery
# Tooling
# Power
# Labor
# Manufacturing
# process
#
# Value
# added $$
#
# Section 1.1/What Is Manufacturing?
# 5
#
#
# a titanium billet, and the product consists of a carbon wafer assembled to the hook
# that protrudes from the right of the frame. The product is an artificial heart valve
# costing thousands of dollars, well worth it for patients who need one. (By the way,
# the surgeon who installs it charges several more thousand dollars.) The titanium
# billet costs a small fraction of the selling price. It measures about 25 mm (1 in)
# in diameter. The frame was machined (a material removal process, Section 1.3.1)
# from the starting billet. Machining time was about one hour. Note the added value
# provided by this operation. Note also the waste in the unit operation, as depicted in
# Figure 1.1(a); the finished frame has only about 5% of the mass of the starting
# workpiece (although the titanium swarf can be recycled).
# The words manufacturing and production are often used interchangeably. The
# author’s view is that production has a broader meaning than manufacturing. To illus- trate,
# one might speak of “crude oil production,” but the phrase “crude oil manufac-
# turing” seems out of place. Yet when used in the context of products such as metal
# parts or automobiles, either word seems okay.
#
#
# 1.1.2 MANUFACTURING INDUSTRIES AND PRODUCTS
#
# Manufacturing is an important commercial activity performed by companies that
# sell products to customers. The type of manufacturing done by a company depends
# on the kinds of products it makes.
#
# Manufacturing Industries
# Industry consists of enterprises and organizations that
# produce or supply goods and services. Industries can be classified as primary, second- ary,
# or tertiary. Primary industries cultivate and exploit natural resources, such as
# agriculture and mining.
#
# but construction and power utilities are also included.
# Tertiary industries constitute the service sector of the economy. A list of specific
# industries in these categories is presented in Table 1.2.
#
# TABLE • 1.2 Specific industries in the primary, secondary, and tertiary categories.
#
# Primary
# Secondary
# Tertiary (service)
# Agriculture
# Forestry
# Fishing
# Livestock
# Quarries
# Mining
# Petroleum
# Aerospace
# Food processing
# Apparel
# Glass, ceramics
# Automotive
# Heavy machinery
# Basic metals
# Paper
# Beverages
# Petroleum refining
# Building materials
# Pharmaceuticals
# Chemicals
# Plastics (shaping)
# Computers
# Power utilities
# Construction
# Publishing
# Consumer appliances
# Textiles
# Electronics
# Tire and rubber
# Equipment
# Wood and furniture
# Fabricated metals
# Banking
# Insurance
# Communications
# Legal
# Education
# Real estate
# Entertainment
# Repair and
# Financial services
# maintenance
# Government
# Restaurant
# Health and medical
# Retail trade
# Hotel
# Tourism
# Information
# Transportation
# Wholesale trade
# cipal activity in this category,
# Secondary industries take the outputs of the primary indus-
# tries and convert them into consumer and capital goods. Manufacturing is the prin-
# Section 1.1/What Is Manufacturing?
# 6
#
#
# This book is concerned with the secondary industries in Table 1.2, which include
# the companies engaged in manufacturing. However, the International Standard
# Industrial Classification (ISIC) used to compile Table 1.2 includes several industries
# whose production technologies are not covered in this text; for example, beverages,
# chemicals, and food processing. In this book, manufacturing means production of
# hardware, which ranges from nuts and bolts to digital computers and military weap-
# ons. Plastic and ceramic products are included, but apparel, paper, pharmaceuticals,
# power utilities, publishing, and wood products are excluded.
#
# Manufactured Products Final products made by the manufacturing industries
# can be divided into two major classes: consumer goods and capital goods. Consumer goods
# are products purchased directly by consumers, such as cars, personal comput- ers, TVs,
# tires, and tennis rackets. Capital goods are those purchased by companies to produce
# goods and/or provide services. Examples of capital goods include aircraft, computers,
# communication equipment, medical apparatus, trucks and buses, railroad locomotives,
# machine tools, and construction equipment. Most of these capital goods are purchased
# by the service industries. It was noted in the introduction that manu- facturing
# accounts for about 12% of gross domestic product and services about 75% of GDP in
# the United States. Yet the manufactured capital goods purchased by the service
# sector are the enablers of that sector. Without the capital goods, the service
# industries could not function.
# In addition to final products, other manufactured items include the materials,
# components, tools, and supplies used by the companies that make the final products.
# Examples of these items include sheet steel, bar stock, metal stampings, machined
# parts, plastic moldings and extrusions, cutting tools, dies, molds, and lubricants.
# Thus, the manufacturing industries consist of a complex infrastructure with vari-
# ous categories and layers of intermediate suppliers with whom the final consumer
# never deals.
# This book is generally concerned with discrete items—individual parts and
# assembled products rather than items produced by continuous processes. A metal
# stamping is a discrete item, but the sheet-metal coil from which it is made is continu-
# ous (almost). Many discrete parts start out as continuous or semicontinuous prod-
# ucts, such as extrusions and electrical wire. Long sections made in almost continuous
# lengths are cut to the desired size. An oil refinery is a better example of a continuous
# process.
#
# Production Quantity and Product Variety The quantity of products made by a
# factory has an important influence on the way its people, facilities, and procedures
# are organized. Annual production quantities can be classified into three ranges: (1)
# low production, quantities in the range 1 to 100 units per year; (2) medium produc-
# tion, from 100 to 10,000 units annually; and (3) high production, 10,000 to millions
# of units. The boundaries between the three ranges are somewhat arbitrary (author’s
# judgment). Depending on the kinds of products, these boundaries may shift by an
# order of magnitude or so.
# Production quantity refers to the number of units produced annually of a particu-
# lar product type. Some plants produce a variety of different product types, each type being
# made in low or medium quantities. Other plants specialize in high production of only
# one product type. It is instructive to identify product variety as a parameter distinct
# from production quantity. Product variety refers to different product designs or types
# that are produced in the plant. Different products have different shapes and
# Section 1.1/What Is Manufacturing?
# 7
#
#
#
#
#
#
#
#
#
#
#
# FIGURE 1.3 Relationship
# between product variety and
# production quantity in discrete
# product manufacturing.
#
# sizes; they perform different functions; they are intended for different markets; some have
# more components than others; and so forth. The number of different product types
# made each year can be counted. When the number of product types made in the
# factory is high, this indicates high product variety.
# There is an inverse correlation between product variety and production quantity
# in terms of factory operations. If a factory’s product variety is high, then its produc-
# tion quantity is likely to be low; but if production quantity is high, then product vari-
# ety will be low, as depicted in Figure 1.3. Manufacturing plants tend to specialize in a
# combination of production quantity and product variety that lies somewhere inside
# the diagonal band in Figure 1.3.
# Although product variety has been identified as a quantitative parameter (the
# number of different product types made by the plant or company), this parameter is
# much less exact than production quantity because details on how much the designs
# differ are not captured simply by the number of different designs. Differences
# between an automobile and an air conditioner are far greater than between an air
# conditioner and a heat pump. Within each product type, there are differences among
# specific models.
# The extent of the product differences may be small or great, as illustrated in the
# automotive industry. Each of the U.S. automotive companies produces cars with two
# or three different nameplates in the same assembly plant, although the body styles
# and other design features are virtually the same. In different plants, the company
# builds heavy trucks. The terms “soft” and “hard” might be used to describe these
# differences in product variety. Soft product variety occurs when there are only small
# differences among products, such as the differences among car models made on the
# same production line. In an assembled product, soft variety is characterized by a
# high proportion of common parts among the models. Hard product variety occurs
# when the products differ substantially, and there are few common parts, if any. The
# difference between a car and a truck exemplifies hard variety.
#
#
# 1.1.3 MANUFACTURING CAPABILITY
#
# A manufacturing plant consists of a set of processes and systems (and people, of
# course) designed to transform a certain limited range of materials into products of
# increased value. These three building blocks—materials, processes, and systems—
# constitute the subject of modern manufacturing. There is a strong interdependence
# among these factors. A company engaged in manufacturing cannot do everything.
# Section 1.1/What Is Manufacturing?
# 8
#
#
# It must do only certain things, and it must do those things well. Manufacturing ca-
# pability refers to the scope of technical and physical capabilities and limitations of
# a manufacturing company and each of its plants. Manufacturing capability has three
# dimensions: (1) technological processing capability, (2) physical size and weight of
# product, and (3) production capacity.
#
# Technological Processing Capability The technological processing capabil- ity
# of a plant (or company) is its available set of manufacturing processes. Certain plants
# perform machining operations, others roll steel billets into sheet stock, and others build
# automobiles. A machine shop cannot roll steel, and a rolling mill can- not build cars.
# The underlying feature that distinguishes these plants is the processes they can
# perform. Technological processing capability is closely related to material type.
# Certain manufacturing processes are suited to certain materials, whereas other
# processes are suited to other materials. By specializing in a certain process or group of
# processes, the plant is simultaneously specializing in certain material types. Tech-
# nological processing capability includes not only the physical processes, but also the
# expertise possessed by plant personnel in these processing technologies. Companies
# must concentrate on the design and manufacture of products that are compatible
# with their technological processing capability.
#
# Physical Product Limitations A second aspect of manufacturing capability is
# imposed by the physical product. A plant with a given set of processes is limited in
# terms of the size and weight of the products that can be accommodated. Large,
# heavy products are difficult to move. To move these products about, the plant must
# be equipped with cranes of the required load capacity. Smaller parts and products
# made in large quantities can be moved by conveyor or other means. The limitation
# on product size and weight extends to the physical capacity of the manufacturing
# equipment as well. Production machines come in different sizes. Larger machines
# must be used to process larger parts. The production and material handling equip-
# ment must be planned for products that lie within a certain size and weight range.
#
# Production Capacity A third limitation on a plant’s manufacturing capability
# is the production quantity that can be produced in a given time period (e.g., month
# or year). This quantity limitation is commonly called plant capacity, or production
# capacity, defined as the maximum rate of production that a plant can achieve under
# assumed operating conditions. The operating conditions refer to number of shifts
# per week, hours per shift, direct labor manning levels in the plant, and so on. These
# factors represent inputs to the manufacturing plant. Given these inputs, how much
# output can the factory produce?
# Plant capacity is usually measured in terms of output units, such as annual tons of steel
# produced by a steel mill, or number of cars produced by a final assembly plant. In
# these cases, the outputs are homogeneous. In cases in which the output units are not
# homogeneous, other factors may be more appropriate measures, such as avail- able
# labor hours of productive capacity in a machine shop that produces a variety of
# parts.
# Materials, processes, and systems are the basic building blocks of manufacturing
# and the three broad subject areas of this book. This introductory chapter provides
# an overview of these three subjects before embarking on a detailed coverage in the
# remaining chapters.
# Section 1.2/Materials in Manufacturing
# 9
#
#
# Materials in Manufacturing
# Most engineering materials can be classified into one of three basic categories:
# (1) metals, (2) ceramics, and (3) polymers. Their chemistries are different, their
# mechanical and physical properties are different, and these differences affect the
# manufacturing processes that can be used to produce products from them. In addi-
# tion to the three basic categories, there are (4) composites—nonhomogeneous mix-
# tures of the other three basic types rather than a unique category. The classification
# of the four groups is pictured in Figure 1.4. This section provides a survey of these
# materials. Chapters 6 through 9 cover the four material types in more detail.
#
#
# 1.2.1 METALS
#
# Metals used in manufacturing are usually alloys, which are composed of two or
# more elements, with at least one being a metallic element. Metals and alloys can be
# divided into two basic groups: (1) ferrous, and (2) nonferrous.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# FIGURE 1.4
# Classification of the
# four engineering
# materials.
# 1.2
#
# Ferrous Metals
#
#
#
# Metals
#
#
#
#
#
#
# Nonferrous
# Metals
#
#
#
# Crystalline
# Ceramics
#
#
#
# Ceramics
#
#
#
#
#
# Glasses
#
# Engineering
# Materials
#
#
#
#
# Thermoplastics
#
#
#
#
#
# Polymers
#
#
# Thermosets
#
#
#
#
#
#
# Elastomers
#
#
#
# Metal Matrix
# Composites
#
#
#
#
# Composites
#
#
# Ceramic Matrix
# Composites
#
#
#
#
#
#
# Polymer Matrix
# Composites
#
#
# Section 1.2/Materials in Manufacturing
# 10
#
#
# Ferrous Metals Ferrous metals are based on iron; the group includes steel and cast
# iron. These metals constitute the most important group commercially, more than three-
# fourths of the metal tonnage throughout the world. Pure iron has limited com- mercial
# use, but when alloyed with carbon, iron has more uses and greater commer- cial value
# than any other metal. Alloys of iron and carbon form steel and cast iron.
# Steel can be defined as an iron–carbon alloy containing 0.02% to 2.11% carbon. It
# is the most important category within the ferrous metal group. Its composition often
# includes other alloying elements as well, such as manganese, chromium, nickel, and
# molybdenum, to enhance the properties of the metal. Applications of steel include
# construction (bridges, I-beams, and nails), transportation (trucks, rails, and rolling
# stock for railroads), and consumer products (automobiles and appliances).
# Cast iron is an alloy of iron and carbon (2% to 4%) used in casting (primarily
# sand casting). Silicon is also present in the alloy (in amounts from 0.5% to 3%), and
# other elements are often added also, to obtain desirable properties in the cast part.
# Cast iron is available in several different forms, of which gray cast iron is the most
# common; its applications include blocks and heads for internal combustion engines.
# Nonferrous Metals Nonferrous metals include the other metallic elements and their
# alloys. In almost all cases, the alloys are more important commercially than the pure
# metals. The nonferrous metals include the pure metals and alloys of aluminum, copper,
# gold, magnesium, nickel, silver, tin, titanium, zinc, and other metals.
#
# 1.2.2 CERAMICS
#
# A ceramic is defined as a compound containing metallic (or semimetallic) and nonme-
# tallic elements. Typical nonmetallic elements are oxygen, nitrogen, and carbon. Ceram-
# ics include a variety of traditional and modern materials. Traditional ceramics, some of
# which have been used for thousands of years, include: clay (abundantly available, con-
# sisting of fine particles of hydrous aluminum silicates and other minerals used in mak-
# ing brick, tile, and pottery); silica (the basis for nearly all glass products); and alumina
# and silicon carbide (two abrasive materials used in grinding). Modern ceramics include
# some of the preceding materials, such as alumina, whose properties are enhanced in
# various ways through modern processing methods. Newer ceramics include: carbides—
# metal carbides such as tungsten carbide and titanium carbide, which are widely used
# as cutting tool materials; and nitrides—metal and semimetal nitrides such as titanium
# nitride and boron nitride, used as cutting tools and grinding abrasives.
# For processing purposes, ceramics can be divided into crystalline ceramics and
# glasses. Different methods of manufacturing are required for the two types.
# Crystalline ceramics are formed in various ways from powders and then fired (heated
# to a temperature below the melting point to achieve bonding between the powders).
# The glass ceramics (namely, glass) can be melted and cast, and then formed in proc-
# esses such as traditional glass blowing.
#
# 1.2.3 POLYMERS
#
# A polymer is a compound formed of repeating structural units called mers, whose
# atoms share electrons to form very large molecules. Polymers usually consist of
# carbon plus one or more other elements such as hydrogen, nitrogen, oxygen, and
# chlorine. Polymers are divided into three categories: (1) thermoplastic polymers,
# (2) thermosetting polymers, and (3) elastomers.
# Section 1.3/Manufacturing Processes
# 11
#
#
# Thermoplastic polymers can be subjected to multiple heating and cooling cycles
# without substantially altering the molecular structure of the polymer. Common
# thermoplastics include polyethylene, polystyrene, polyvinylchloride, and nylon.
# Thermosetting polymers chemically transform (cure) into a rigid structure upon
# cooling from a heated plastic condition; hence the name thermosetting. Members
# of this type include phenolics, amino resins, and epoxies. Although the name “ther-
# mosetting” is used, some of these polymers cure by mechanisms other than heating.
# Elastomers are polymers that exhibit significant elastic behavior; hence the name
# elastomer. They include natural rubber, neoprene, silicone, and polyurethane.
#
#
# 1.2.4 COMPOSITES
#
# Composites do not really constitute a separate category of materials; they are mix-
# tures of the other three types. A composite is a material consisting of two or more
# phases that are processed separately and then bonded together to achieve proper-
# ties superior to those of its constituents. The term phase refers to a homogeneous
# mass of material, such as an aggregation of grains of identical unit cell structure in a
# solid metal. The usual structure of a composite consists of particles or fibers of one
# phase mixed in a second phase, called the matrix.
# Composites are found in nature (e.g., wood), and they can be produced synthetically.
# The synthesized type is of greater interest here, and it includes glass fibers in a polymer
# matrix, such as fiber-reinforced plastic; polymer fibers of one type in a matrix of a sec-
# ond polymer, such as an epoxy-Kevlar composite; and ceramic in a metal matrix, such
# as a tungsten carbide in a cobalt binder to form a cemented carbide cutting tool.
# Properties of a composite depend on its components, the physical shapes of the
# components, and the way they are combined to form the final material. Some com-
# posites combine high strength with light weight and are suited to applications such
# as aircraft components, car bodies, boat hulls, tennis rackets, and fishing rods. Other
# composites are strong, hard, and capable of maintaining these properties at elevated
# temperatures, for example, cemented carbide cutting tools.
#
# Manufacturing Processes
# A manufacturing process is a designed procedure that results in physical and/or
# chemical changes to a starting work material with the intention of increasing the
# value of that material. A manufacturing process is usually carried out as a unit oper- ation,
# which means that it is a single step in the sequence of steps required to trans- form
# the starting material into a final product. Manufacturing operations can be divided
# into two basic types: (1) processing operations and (2) assembly operations. A
# processing operation transforms a work material from one state of completion to
# a more advanced state that is closer to the final desired product. It adds value by
# changing the geometry, properties, or appearance of the starting material. In general,
# processing operations are performed on discrete work parts, but certain processing
# operations are also applicable to assembled items (e.g., painting a spot-welded car
# body). An assembly operation joins two or more components to create a new entity,
# called an assembly, subassembly, or some other term that refers to the joining proc-
# ess (e.g., a welded assembly is called a weldment). A classification of manufacturing
# processes is presented in Figure 1.5. Some of the basic processes used in modern
# manufacturing date from antiquity (Historical Note 1.2).
# 1.3
# Section 1.3/Manufacturing Processes
# 12
#
# Material
# removal
# Solidification
# processes
# Manufacturing
# processes
# Processing
# operations
# Particulate
# processing
# Shaping
# processes
# Assembly
# operations
# Coating and
# deposition processes
# Deformation
# processes
# Adhesive
# bonding
# Brazing and
# soldering
# Permanent
# joining processes
# Welding
# Cleaning and
# surface treatments
# Surface processing
# operations
# Permanent
# fastening methods
# Mechanical
# fastening
# Threaded
# fasteners
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# FIGURE 1.5
# Classification of
# manufacturing
# processes.
#
#
#
#
#
# Property
# enhancing processes
# Heat
# treatment
# Historical Note 1.2
# Manufacturing materials and processes
#
# Although most of the historical developments that form
# Gold was found by early humans in relatively pure form
# the modern practice of manufacturing have occurred
# in nature; it could be hammered into shape. Copper
# only during the last few centuries (Historical Note 1.1), was probably the first metal to be extracted from ores,
# several of the basic fabrication processes date as far thus requiring smelting as a processing technique.
# back as the Neolithic period (circa 8000–3000 B.C.E.). It Copper could not be hammered readily because it
# was during this period that processes such as the fol-
# strain hardened; instead, it was shaped by casting
# lowing were developed: carving and other woodwork-
#
# (Historical Note 10.1). Other metals used during this
# ing, hand forming and firing of clay pottery, grinding
# period were silver and tin. It was discovered that cop-
# and polishing of stone, spinning and weaving of tex-
# per alloyed with tin produced a more workable metal
# tiles, and dyeing of cloth.
#
#
# than copper alone (casting and hammering could both
# Metallurgy and metalworking also began during
# be used). This heralded the important period known as
# the Neolithic period, in Mesopotamia and other areas
# the Bronze Age (circa 3500–1500 B.C.).
# around the Mediterranean. It either spread to, or de-
#
# Iron was also first smelted during the Bronze Age.
# veloped independently in, regions of Europe and Asia.
# Meteorites may have been one source of the metal,
# Section 1.3/Manufacturing Processes
# 13
#
#
#
# but iron ore was also mined. Temperatures required to
# reduce iron ore to metal are significantly higher than for
# copper, which made furnace operations more difficult.
# Other processing methods were also more difficult for
# the same reason. Early blacksmiths learned that when
# certain irons (those containing small amounts of car-
# bon) were sufficiently heated and then quenched,
# they became very hard. This permitted grinding a very
# sharp cutting edge on knives and weapons, but it also
# made the metal brittle. Toughness could be increased
# by reheating at a lower temperature, a process known
# as tempering. What we have described is, of course,
# the heat treatment of steel. The superior properties of
# steel caused it to succeed bronze in many applica-
# tions (weaponry, agriculture, and mechanical devices).
# The period of its use has subsequently been named
# the Iron Age (starting around 1000 B.C.). It was not un-
# til much later, well into the nineteenth century, that the
# demand for steel grew significantly and more modern
# steelmaking techniques were developed (Historical
# Note 6.1).
# The beginnings of machine tool technology oc-
# curred during the Industrial Revolution. During the peri-
# od 1770–1850, machine tools were developed for most
# of the conventional material removal processes,
# such as boring, turning, drilling, milling, shaping,
# and planing (Historical Note 21.1). Many of the individ-
# ual processes predate the machine tools by centuries;
# for example, drilling and sawing (of wood) date from
# ancient times, and turning (of wood) from around the
# time of Christ.
# Assembly methods were used in ancient cultures to
# make ships, weapons, tools, farm implements,
# machinery, chariots and carts, furniture, and garments.
# The earliest processes included binding with twine
# and rope, riveting and nailing, and soldering. Around
# 2000 years ago, forge welding and adhesive bond-
# ing had been developed. Widespread use of screws,
# bolts, and nuts as fasteners—so common in today’s
# assembly—required the development of machine tools
# that could accurately cut the required helical shapes
# (e.g., Maudsley’s screw cutting lathe, 1800). It was not
# until around 1900 that fusion welding proc- esses
# started to be developed as assembly techniques
# (Historical Note 28.1).
# Natural rubber was the first polymer to be used in
# manufacturing (if we exclude wood, which is a polymer
# composite). The vulcanization process, discovered by
# Charles Goodyear in 1839, made rubber a useful engi-
# neering material (Historical Note 8.2). Subsequent de-
# velopments included plastics such as cellulose nitrate
# in 1870, Bakelite in 1900, polyvinylchloride in 1927, pol-
# yethylene in 1932, and nylon in the late 1930s (Histori-
# cal Note 8.1). Processing requirements for plastics led
# to the development of injection molding (based on die
# casting, one of the metal casting processes) and other
# polymer shaping techniques.
# Electronics products have imposed unusual de-
# mands on manufacturing in terms of miniaturization.
# The evolution of the technology has been to package
# more and more devices into a smaller area—in some
# cases millions of transistors onto a flat piece of semi-
# conductor material that is only 12 mm (0.50 in) on a
# side. The history of electronics processing and pack-
# aging dates from around 1960 (Historical Notes 33.1,
# 34.1, and 34.2).
#
#
#
# 1.3.1 PROCESSING OPERATIONS
#
# A processing operation uses energy to alter a work part’s shape, physical properties,
# or appearance to add value to the material. The forms of energy include mechani-
# cal, thermal, electrical, and chemical. The energy is applied in a controlled way by
# means of machinery and tooling. Human energy may also be required, but the hu-
# man workers are generally employed to control the machines, oversee the opera-
# tions, and load and unload parts before and after each cycle of operation. A general
# model of a processing operation is illustrated in Figure 1.1(a). Material is fed into the
# process, energy is applied by the machinery and tooling to transform the material,
# and the completed work part exits the process. Most production operations produce
# waste or scrap, either as a natural aspect of the process (e.g., removing material as in
# machining) or in the form of occasional defective pieces. It is an important objective
# in manufacturing to reduce waste in either of these forms.
# More than one processing operation is usually required to transform the starting
# material into final form. The operations are performed in the particular sequence
# required to achieve the geometry and condition defined by the design specification.
# Section 1.3/Manufacturing Processes
# 14
#
#
# Three categories of processing operations are distinguished: (1) shaping opera-
# tions, (2) property-enhancing operations, and (3) surface processing operations.
# Shaping operations alter the geometry of the starting work material by vari-
# ous methods. Common shaping processes include casting, forging, and machining.
# Property-enhancing operations add value to the material by improving its physical
# properties without changing its shape. Heat treatment is the most common example.
# Surface processing operations are performed to clean, treat, coat, or deposit mate-
# rial onto the exterior surface of the work. Common examples of coating are plating
# and painting. Shaping processes are covered in Parts III through VI, corresponding
# to the four main categories of shaping processes in Figure 1.5. Property-enhancing
# processes and surface processing operations are covered in Part VII.
#
# Shaping Processes Most shape processing operations apply heat, mechanical
# force or a combination of these to effect a change in geometry of the work material.
# There are various ways to classify the shaping processes. The classification used in this
# book is based on the state of the starting material, by which there are four categories:
# (1) solidification processes, in which the starting material is a heated liquid or semif- luid
# that cools and solidifies to form the part geometry; (2) particulate processing, in which
# the starting material is a powder, and the powders are formed and heated into the
# desired geometry; (3) deformation processes, in which the starting material is a
# ductile solid (commonly metal) that is deformed to shape the part; and (4) material
# ...
# falls in between. HCP metals show poor ductility and are generally difficult to
# deform at room temperature. Metals with BCC structure would figure to have the
# highest ductility, if the number of slip directions were the only criterion. However,
# nature is not so simple. These metals are generally stronger than the others, which
# complicates the issue, and the BCC metals usually require higher stresses to cause
# slip. In fact, some of the BCC metals exhibit poor ductility. Low carbon steel is a
# notable exception; although relatively strong, it is widely used with great commer-
# cial success in sheet-metal-forming operations, where it exhibits good ductility. The
# FCC metals are generally the most ductile of the three crystal structures, combining
# a good number of slip directions with (usually) relatively low to moderate strength.
# All three of these metal structures become more ductile at elevated temperatures,
# and this fact is often exploited in shaping them.
# Dislocations play an important role in facilitating slip in metals. When a lattice
# structure containing an edge dislocation is subjected to a shear stress, the material
# deforms much more readily than in a perfect structure. This is explained by the fact
# that the dislocation is put into motion within the crystal lattice in the presence of the
# stress, as shown in the series of sketches in Figure 2.12. Why is it easier to move a dis-
# location through the lattice than it is to deform the lattice itself? The answer is that
# the atoms at the edge dislocation require a smaller displacement within the distorted lattice
# structure to reach a new equilibrium position. Thus, a lower energy level is needed
# to realign the atoms into the new positions than if the lattice were missing the
# dislocation. A lower stress level is therefore required to effect the deformation.
# Because the new position manifests a similar distorted lattice, movement of atoms
# at the dislocation continues at the lower stress level.
# The slip phenomenon and the influence of dislocations have been explained here
# on a very microscopic basis. On a larger scale, slip occurs many times over
# Section 2.3/Crystalline Structures
# 46
#
#
#
# FIGURE 2.12  Effect of dislocations in the lattice structure under stress. In the series of diagrams, the
# movement of the dislocation allows deformation to occur under a lower stress than in a perfect lattice.
#
#
# throughout the metal when subjected to a deforming load, thus causing it to ex-
# hibit the familiar macroscopic behavior of stretching, compressing, or bending.
# Dislocations represent a good-news–bad-news situation. Because of dislocations,
# the metal is more ductile and yields more readily to plastic deformation (forming)
# during manufacturing. However, from a product design viewpoint, the metal is not
# nearly as strong as it would be in the absence of dislocations.
# Twinning is a second way in which metal crystals plastically deform. Twinning
# can be defined as a mechanism of plastic deformation in which atoms on one side of
# a plane (called the twinning plane) are shifted to form a mirror image of the other
# side of the plane. It is illustrated in Figure 2.13. The mechanism is important in HCP metals
# (e.g., magnesium, zinc) because they do not slip readily. Besides structure, another
# factor in twinning is the rate of deformation. The slip mechanism requires more
# time than twinning, which can occur almost instantaneously. Thus, when the
# deformation rate is very high, metals twin that would otherwise slip. Low carbon
# steel is an example that illustrates this rate sensitivity; when subjected to high strain
# rates it twins, whereas at moderate rates it deforms by slip.
#
#
#
#
#
#
#
#
# FIGURE 2.13 Twinning
# involves the formation
# of an atomic mirror
# image (i.e., a “twin”)
# on the opposite side
# of the twinning plane:
# (a) before and (b) after
# twinning.
#
#
#
#
#
#
#
#
# (a)
# (b)
# Section 2.4/Noncrystalline (Amorphous) Structures
# 47
#
#
# 2.3.4 GRAINS AND GRAIN BOUNDARIES IN METALS
#
# A given block of metal may contain millions of individual crystals, called grains.
# Each grain has its own unique lattice orientation; but collectively, the grains are ran-
# domly oriented within the block. Such a structure is referred to as polycrystalline. It
# is easy to understand how such a structure is the natural state of the material. When
# the block is cooled from the molten state and begins to solidify, nucleation of indi-
# vidual crystals occurs at random positions and orientations throughout the liquid.
# As
# these crystals grow they finally interfere with each other, forming at their interface a
# surface defect—a grain boundary. The grain boundary consists of a transition zone,
# perhaps only a few atoms thick, in which the atoms are not aligned with either grain.
# The size of the grains in the metal block is determined by the number of nucleation
# sites in the molten material and the cooling rate of the mass, among other factors. In
# a casting process, the nucleation sites are often created by the relatively cold walls
# of the mold, which motivates a somewhat preferred grain orientation at these walls.
# Grain size is inversely related to cooling rate: Faster cooling promotes smaller
# grain size, whereas slower cooling has the opposite effect. Grain size is important
# in metals because it affects mechanical properties. Smaller grain size is generally
# preferable from a design viewpoint because it means higher strength and hard-
# ness. It is also desirable in certain manufacturing operations (e.g., metal forming),
# because it means higher ductility during deformation and a better surface on the
# finished product.
# Another factor influencing mechanical properties is the presence of grain
# boundaries in the metal. They represent imperfections in the crystalline structure
# that interrupt the continued movement of dislocations. This helps to explain why
# smaller grain size—therefore more grains and more grain boundaries—increases the
# strength of the metal. By interfering with dislocation movement, grain boundaries
# also contribute to the characteristic property of a metal to become stronger as it is
# deformed. The property is called strain hardening, and it is examined more closely
# in Chapter 3 on mechanical properties.
#
# Noncrystalline (Amorphous) Structures
# Many important materials are noncrystalline—liquids and gases, for example. Water
# and air have noncrystalline structures. A metal loses its crystalline structure when
# it is melted. Mercury is a liquid metal at room temperature, with its melting point
# of -38°C (-37°F). Important classes of engineering materials have a noncrystalline
# form in their solid state; the term amorphous is often used to describe these materi-
# als. Glass, many plastics, and rubber fall into this category. Many important plastics
# are mixtures of crystalline and noncrystalline forms. Even metals can be amorphous rather
# than crystalline, given that the cooling rate during transformation from liquid to solid
# is fast enough to inhibit the atoms from arranging themselves into their pre- ferred
# regular patterns. This can happen, for instance, if the molten metal is poured
# between cold, closely spaced, rotating rolls.
# Two closely related features distinguish noncrystalline from crystalline materials:
# (1) absence of a long-range order in the molecular structure, and (2) differences in
# melting and thermal expansion characteristics.
# The difference in molecular structure can be visualized with reference to Fig-
# ure 2.14. The closely packed and repeating pattern of the crystal structure is shown
# on the left; and the less dense and random arrangement of atoms in the noncrystalline
# 2.4
# Section 2.4/Noncrystalline (Amorphous) Structures
# 48
#
#
#
#
# FIGURE 2.14 Illustration of difference
# in structure between: (a) crystalline
# and (b) noncrystalline materials. The
# crystal structure is regular, repeating,
# and denser, while the noncrystalline
# structure is more loosely packed and
# random.
#
#
# material on the right. The difference is demonstrated by a metal when it melts. The
# more loosely packed atoms in the molten metal show an increase in volume (reduction
# in density) compared with the material’s solid crystalline state. This effect is character-
# istic of most materials when melted (ice is a notable exception; liquid water is denser
# than solid ice). It is a general characteristic of liquids and solid amorphous materials
# that they are absent of long-range order as on the right in our figure.
# The melting phenomenon will now be examined in more detail, and in doing so,
# the second important difference between crystalline and noncrystalline structures is
# illustrated. As indicated above, a metal experiences an increase in volume when it
# melts from the solid to the liquid state. For a pure metal, this volumetric change occurs
# rather abruptly, at a constant temperature (i.e., the melting temperature Tm), as indi-
# cated in Figure 2.15. The change represents a discontinuity from the slopes on either
# side in the plot. The gradual slopes characterize the metal’s thermal expansion—the
# change in volume as a function of temperature, which is usually different in the solid
# and liquid states. Associated with the sudden volume increase as the metal transforms from
# solid to liquid at the melting point is the addition of a certain quantity of heat, called
# the heat of fusion, which causes the atoms to lose the dense, regular arrange- ment
# of the crystalline structure. The process is reversible; it operates in both direc- tions.
# If the molten metal is cooled through its melting temperature, the same abrupt change
# in volume occurs (except that it is a decrease), and the same quantity of heat is given
# off by the metal.
# An amorphous material exhibits quite different behavior than that of a pure
# metal when it changes from solid to liquid, as shown in Figure 2.15. The process
# is again reversible, but observe the behavior of the amorphous material during
#
#
#
#
#
#
#
#
#
#
#
#
# FIGURE 2.15 Characteristic change in
# volume for a pure metal (a crystalline
# structure), compared to the same
# volumetric changes in glass
# (a noncrystalline structure).
# Section 2.5/Engineering Materials
# 49
#
#
# cooling from the liquid state, rather than during melting from the solid, as before.
# Glass (silica, SiO2) is used to illustrate. At high temperatures, glass is a true liquid,
# and the molecules are free to move about as in the usual definition of a liquid. As
# the glass cools, it gradually transforms into the solid state, going through a transi-
# tion phase, called a supercooled liquid, before finally becoming rigid. It does not
# show the sudden volumetric change that is characteristic of crystalline materials;
# instead it passes through its melting temperature Tm without a change in its thermal
# expansion slope. In this supercooled liquid region, the material becomes increas-
# ingly viscous as the temperature continues to decrease. As it cools further, a point
# is finally reached at which the supercooled liquid converts to a solid. This is called
# the glass-transition temperature Tg. At this point, there is a change in the thermal
# expansion slope. (It might be more precise to refer to it as the thermal contraction
# slope; however, the slope is the same for expansion and contraction). The rate of
# thermal expansion is lower for the solid material than for the supercooled liquid.
# The difference in behavior between crystalline and noncrystalline materials can
# be traced to the response of their respective atomic structures to changes in temper-
# ature. When a pure metal solidifies from the molten state, the atoms arrange them-
# selves into a regular and recurring structure. This crystal structure is much more
# compact than the random and loosely packed liquid from which it formed. Thus,
# the process of solidification produces the abrupt volumetric contraction observed
# in Figure 2.15 for the crystalline material. By contrast, amorphous materials do not
# achieve this repeating and closely packed structure at low temperatures. The atomic
# structure is the same random arrangement as in the liquid state; thus, there is no
# abrupt volumetric change as these materials transition from liquid to solid.
#
# Engineering Materials
# This section summarizes how atomic structure, bonding, and crystal structure (or
# absence thereof) are related to the type of engineering material: metals, ceramics,
# and polymers.
#
# Metals Metals have crystalline structures in the solid state, almost without excep-
# tion. The unit cells of these crystal structures are almost always BCC, FCC, or HCP.
# The atoms of the metals are held together by metallic bonding, which means that
# their valence electrons can move about with relative freedom (compared with the
# other types of atomic and molecular bonding). These structures and bonding gener-
# ally make the metals strong and hard. Many of the metals are quite ductile (capable of being
# deformed, which is useful in manufacturing), especially the FCC metals. Other general
# properties of metals related to structure and bonding include high electri- cal and
# thermal conductivity, opaqueness (impervious to light rays), and reflectivity
# (capacity to reflect light rays).
#
# Ceramics Ceramic molecules are characterized by ionic or covalent bonding, or
# both. The metallic atoms release or share their outermost electrons to the nonme-
# tallic atoms, and a strong attractive force exists within the molecules. The general
# properties that result from these bonding mechanisms include high hardness and
# stiffness (even at elevated temperatures) and brittleness (no ductility). The bond-
# ing also means that ceramics are electrically insulating (nonconducting), refractory
# (thermally resistant), and chemically inert.
# 2.5
# Section 1.6/Recent Developments in Manufacturing
# 50
#
#
# Ceramics possess either a crystalline or noncrystalline
# structure. Most ceramics have a crystal structure, whereas glasses
# based on silica (SiO2) are amorphous. In certain cases, either
# structure can exist in the same ceramic material. For example,
# silica occurs in nature as crystalline quartz. When this mineral is
# melted and then cooled, it solidifies to form fused silica, which
# has a noncrystalline structure.
#
# Polymers A polymer molecule consists of many repeating
# mers to form very large molecules held together by covalent
# bonding. Elements in polymers are usu- ally carbon plus one or
# more other elements such as hydrogen, nitrogen, oxygen, and
# chlorine. Secondary bonding (van der Waals) holds the
# molecules
# together
# within
# the
# aggregate
# material
# (intermolecular bonding). Polymers have either a glassy
# structure or mixture of glassy and crystalline. There are
# differences among the three polymer types. In thermoplastic
# polymers, the molecules consist of long chains of mers in a
# linear structure. These materials can be heated and cooled
# without substantially altering their linear structure. In
# thermosetting polymers, the molecules transform into a rigid,
# three-dimensional structure on cooling from a heated plastic
# condition. If thermosetting polymers are reheated, they
# degrade chemically rather than soften. Elastomers have large
# molecules with coiled struc- tures. The uncoiling and recoiling
# of the molecules when subjected to stress cycles motivate the
# aggregate material to exhibit its characteristic elastic behavior.
# The molecular structure and bonding of polymers provide them
# with the fol- lowing typical properties: low density, high
# electrical resistivity (some polymers are used as insulating
# materials), and low thermal conductivity. Strength and stiff- ness
# of polymers vary widely. Some are strong and rigid (although
# not matching the strength and stiffness of metals or ceramics),
# whereas others exhibit highly elastic behavior.

# %%
os.environ["OPENAI_API_KEY"] = api_key
# index = VectorStoreIndex.from_documents(documents)
# index.storage_context.persist() # Save the index to disk
# index

# %%
# ## To reload you can run 
from llama_index.core import StorageContext, load_index_from_storage

# rebuild storage context
storage_context = StorageContext.from_defaults(persist_dir="./storage")
# load index
index = load_index_from_storage(storage_context)

# %% [markdown]
# ## This section below can virtualize the chunk size

# %%
from llama_index.core.node_parser import SentenceSplitter

text_splitter = SentenceSplitter(chunk_size=300, chunk_overlap=100)
nodes = text_splitter.get_nodes_from_documents(documents=documents)

# %%
nodes
# Out:
# [TextNode(id_='b5429916-1466-47a7-af8f-af8217f05132', embedding=None, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='cc53946f-a0a8-43dc-acee-53fc5c09129e', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='e8096f063b567d87c66be4a39d33a8de5caab4efd44994aa71214b8be272fb9a'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='8fceadc7-0e0f-495c-9469-016519316184', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='a00c3e7e5df6d3b4431a4d16d07d27af6c9bd9df1918af9dd3b1b115b0f881d9')}, text='Introduction \nand Overview of \nManufacturing \n \n \n \n \nChapter Contents \n1.1 What Is Manufacturing? \n1.1.1 Manufacturing Defined \n1.1.2 Manufacturing Industries and \nProducts \n1.1.3 Manufacturing Capability \n1.2 Materials in Manufacturing \n1.2.1 Metals \n1.2.2 Ceramics \n1.2.3 Polymers \n1.2.4 Composites \n1.3 Manufacturing Processes \n1.3.1 Processing Operations \n1.3.2 Assembly Operations \n1.3.3 Production Machines and Tooling \n1.4 Production Systems \n1.4.1 Production Facilities \n1.4.2 Manufacturing Support Systems \n1.5 Manufacturing Economics \n1.5.1 Production Cycle Time Analysis \n1.5.2 Manufacturing Cost Models \n1.6 Recent Developments in Manufacturing \nMaking things has been an essential activity of human \ncivilizations since before recorded history. Today, the \nterm manufacturing is used for this activity. For techno- \nlogical and economic reasons, manufacturing is impor- \ntant to the welfare of the United States and most other \ndeveloped and developing nations. Technology can be \ndefined as the application of science to provide society \nand its members with those things that are needed or \ndesired.', mimetype='text/plain', start_char_idx=0, end_char_idx=1115, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='8fceadc7-0e0f-495c-9469-016519316184', embedding=None, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='cc53946f-a0a8-43dc-acee-53fc5c09129e', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='e8096f063b567d87c66be4a39d33a8de5caab4efd44994aa71214b8be272fb9a'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='b5429916-1466-47a7-af8f-af8217f05132', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='6ebb160f59fcf2697f2c6694ea027ca1e6aff9cf64dd666068d3340055d6a9db'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='4e17253c-e277-4536-b4ed-695077fa8fbc', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='b93daf8121459f6bd86223319d8855030251633e86258d6569cdc419a417af71')}, text='Today, the \nterm manufacturing is used for this activity. For techno- \nlogical and economic reasons, manufacturing is impor- \ntant to the welfare of the United States and most other \ndeveloped and developing nations. Technology can be \ndefined as the application of science to provide society \nand its members with those things that are needed or \ndesired. Technology affects our daily lives, directly and \nindirectly, in many ways. Consider the list of products in \nTable 1.1. They represent various technologies that help our \nsociety and its members to live better. What do all these \nproducts have in common? They are all manufac- tured. \nThese technological wonders would not be avail- able to \nour society if they could not be manufactured. \nManufacturing is the critical factor that makes technol- \nogy possible. \nEconomically, manufacturing is an important means \nby which a nation creates material wealth. In the Unit- \ned States, the manufacturing industries account for \nonly about 12% of gross domestic product (GDP). A \ncountry’s natural resources, such as agricultural lands, \nmineral deposits, and oil reserves, also create wealth.', mimetype='text/plain', start_char_idx=759, end_char_idx=1905, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='4e17253c-e277-4536-b4ed-695077fa8fbc', embedding=None, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='cc53946f-a0a8-43dc-acee-53fc5c09129e', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='e8096f063b567d87c66be4a39d33a8de5caab4efd44994aa71214b8be272fb9a'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='8fceadc7-0e0f-495c-9469-016519316184', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='cf98de0dcdeca30e1c70c26538d6baf8dc8b32fc5a4c18485d850331ee5f9931'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='26d8ab96-ff12-477e-a744-beb29be1d3c4', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='7a1e720fb1280b35d783c03837488f06bd34bea4eb8e5e31655fb6a239ed329f')}, text='Manufacturing is the critical factor that makes technol- \nogy possible. \nEconomically, manufacturing is an important means \nby which a nation creates material wealth. In the Unit- \ned States, the manufacturing industries account for \nonly about 12% of gross domestic product (GDP). A \ncountry’s natural resources, such as agricultural lands, \nmineral deposits, and oil reserves, also create wealth. \nIn the U.S., agriculture, mining, and similar industries \naccount for less than 5% of GDP (agriculture alone is \nonly about 1%). Construction and public utilities make \nup around 5%. The rest is service industries, which in- \nclude retail, transportation, banking, communication, \neducation, and government. The service sector ac- \ncounts for more than 75% of U.S. GDP. Government \n(federal, state, and local) accounts for more of GDP \nthan the manufacturing sector; however, government \nservices do not create wealth. In the modern global \neconomy, a nation must have a strong manufacturing \nbase (or it must have significant natural resources) if it \nis to provide a strong economy and a high standard of \nliving for its people.', mimetype='text/plain', start_char_idx=1507, end_char_idx=2637, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='26d8ab96-ff12-477e-a744-beb29be1d3c4', embedding=None, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='cc53946f-a0a8-43dc-acee-53fc5c09129e', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='e8096f063b567d87c66be4a39d33a8de5caab4efd44994aa71214b8be272fb9a'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='4e17253c-e277-4536-b4ed-695077fa8fbc', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='e879d58088c98008cb203b6693a5bf42c7b038be163487d64c9a07cda958639b'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='484b53d4-18e9-4563-ad9e-7a37bd2bd5ca', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='b352f51fa5033dce3bf19454b0679dac952d3251119334e2a354c15b900d6bad')}, text='GDP. Government \n(federal, state, and local) accounts for more of GDP \nthan the manufacturing sector; however, government \nservices do not create wealth. In the modern global \neconomy, a nation must have a strong manufacturing \nbase (or it must have significant natural resources) if it \nis to provide a strong economy and a high standard of \nliving for its people. \n1 \n1 \nSection 1.1/What Is Manufacturing? \n2 \n \n \nTABLE • 1.1 Products representing various technologies, most of which affect nearly all of us.', mimetype='text/plain', start_char_idx=2272, end_char_idx=2782, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='484b53d4-18e9-4563-ad9e-7a37bd2bd5ca', embedding=None, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='cc53946f-a0a8-43dc-acee-53fc5c09129e', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='e8096f063b567d87c66be4a39d33a8de5caab4efd44994aa71214b8be272fb9a'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='26d8ab96-ff12-477e-a744-beb29be1d3c4', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='c9ce2afd59c6570e2f64960c84c1f66430408180073587d6e24e4ad2e5a3401e'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='b46e5612-1d18-4b91-b4eb-3bcaf803e4b4', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='fc9089e1fc1e110058fe4f075fbceeda576d497483c21781556b77b454f1b498')}, text='In the modern global \neconomy, a nation must have a strong manufacturing \nbase (or it must have significant natural resources) if it \nis to provide a strong economy and a high standard of \nliving for its people. \n1 \n1 \nSection 1.1/What Is Manufacturing? \n2 \n \n \nTABLE • 1.1 Products representing various technologies, most of which affect nearly all of us. \n \nAthletic shoes \nE-book reader \nOne-piece molded plastic patio chair \nAutomatic teller machine \nFax machine \nOptical scanner \nAutomatic dishwasher \nHand-held electronic calculator \nPersonal computer (PC) \nBallpoint pen \nHigh density PC diskette \nPhotocopying machine \nCamcorder \nHome security system \nPull-tab beverage cans \nCell phone \nHybrid gas-electric automobile \nQuartz crystal wrist watch \nCompact disc (CD) \nIndustrial robot \nSelf-propelled mulching lawnmower \nCompact disc player \nInk-jet color printer \nSmart phone \nCompact fluorescent light bulb \nLCD and Plasma TVs \nSupersonic aircraft \nContact lenses \nMagnetic resonance imaging (MRI) \nTablet computer \nDigital camera \nmachine for medical diagnosis \nTennis racket of composite materials \nDigital video disc (DVD) \nMedicines \nVideo games \nDigital video disc player \nMicrowave oven \nWashing machine and dryer \n \n \nThis opening chapter considers some general topics about manufacturing.', mimetype='text/plain', start_char_idx=2426, end_char_idx=3731, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='b46e5612-1d18-4b91-b4eb-3bcaf803e4b4', embedding=None, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='cc53946f-a0a8-43dc-acee-53fc5c09129e', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='e8096f063b567d87c66be4a39d33a8de5caab4efd44994aa71214b8be272fb9a'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='484b53d4-18e9-4563-ad9e-7a37bd2bd5ca', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='d37b80fc0cc6115253792c187a2b52bb876f153d709db0fd19bf076b0e1bfe60'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='ffc1210c-2ed2-4510-8ecf-d36bd292b563', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='42072ca552a9dd8d8c1a83707fbc86fbcc46e0b17aa749d1b4e2d8bebf73e786')}, text='What is \nmanufacturing? How is it organized in industry? What are the materials, processes, \nand systems by which it is accomplished? \n \nWhat Is Manufacturing? \nThe word manufacture is derived from two Latin words, manus (hand) and factus \n(make); the combination means made by hand. The English word manufacture is \nseveral centuries old, and “made by hand” accurately described the manual methods \nused when the word was first coined.1 Most modern manufacturing is accomplished \nby automated and computer-controlled machinery (Historical Note 1.1). \n \n \n \n1As a noun, the word manufacture first appeared in English around 1567 A.D. As a verb, it first appeared \naround 1683 A.D. \n. \n \nThe history of manufacturing can be separated into  weapons, scrolls, pottery and glassware, and other \ntwo subjects: (1) the discovery and invention of mate-  products of the time, but the procedures were largely \nrials and processes to make things, and (2) the devel-  based on handicraft. \nopment of the systems of production. The materials   The systems aspects of manufacturing are examined \nand processes to make things predate the systems  here, and the materials and processes are discussed in \nby several millennia.', mimetype='text/plain', start_char_idx=3732, end_char_idx=4943, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='ffc1210c-2ed2-4510-8ecf-d36bd292b563', embedding=None, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='cc53946f-a0a8-43dc-acee-53fc5c09129e', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='e8096f063b567d87c66be4a39d33a8de5caab4efd44994aa71214b8be272fb9a'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='b46e5612-1d18-4b91-b4eb-3bcaf803e4b4', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='f80f9fb06b1f1a67eceaffc429eabf3e0b0bfa47ef8b6fbe478069cebe8ace8f'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='52564d79-539c-422f-9246-2d2c1794d537', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='310f96ecfcae9460a25bd8bbf0727e12ff8fe802b94c2dfcd86fe00d55026fa5')}, text='opment of the systems of production. The materials   The systems aspects of manufacturing are examined \nand processes to make things predate the systems  here, and the materials and processes are discussed in \nby several millennia. Some of the processes—casting, Historical Note 1.2. Systems of manufacturing refer \nhammering (forging), and grinding—date back 6000 to the ways of organizing people and equipment so years \nor more. The early fabrication of implements and that production can be performed more efficiently. weapons \nwas accomplished more as crafts and trades\nSeveral historical events and discoveries stand out than \nmanufacturing as it is known today. The ancient as having had a major impact on the development of Romans \nhad what might be called factories to produce  modern manufacturing systems. \nSection 1.1/What Is Manufacturing? \n3 \n \n \n \nCertainly one significant discovery was the principle \nof division of labor—dividing the total work into tasks \nand having individual workers each become a special- \nist at performing only one task. This principle had been \npracticed for centuries, but the economist Adam Smith \n(1723–1790) is credited with first explaining its eco- \nnomic significance in The Wealth of Nations.', mimetype='text/plain', start_char_idx=4712, end_char_idx=5953, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='52564d79-539c-422f-9246-2d2c1794d537', embedding=None, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='cc53946f-a0a8-43dc-acee-53fc5c09129e', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='e8096f063b567d87c66be4a39d33a8de5caab4efd44994aa71214b8be272fb9a'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='ffc1210c-2ed2-4510-8ecf-d36bd292b563', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='6a667ce6894e85c609906044b2b0cb209e1620375fafd4910d9d33fe69218c49'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='0d679692-dc49-4312-b8f3-2a2016ad671d', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='bd487f7005e58a6ca97af1d4c3417192cd0788375f2ad29fcd158324b83e148f')}, text='Section 1.1/What Is Manufacturing? \n3 \n \n \n \nCertainly one significant discovery was the principle \nof division of labor—dividing the total work into tasks \nand having individual workers each become a special- \nist at performing only one task. This principle had been \npracticed for centuries, but the economist Adam Smith \n(1723–1790) is credited with first explaining its eco- \nnomic significance in The Wealth of Nations. \nThe Industrial Revolution (circa 1760–1830) had \na major impact on production in several ways. It \nmarked the change from an economy based on agri- \nculture and handicraft to one based on industry and \nmanufacturing. The change began in England, where a \nseries of machines were invented and steam power \nreplaced water, wind, and animal power. These ad- \nvances gave British industry significant advantages \nover other nations, and England attempted to restrict \nexport of the new technologies. However, the revo- \nlution eventually spread to other European countries \nand the United States.', mimetype='text/plain', start_char_idx=5529, end_char_idx=6547, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='0d679692-dc49-4312-b8f3-2a2016ad671d', embedding=None, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='cc53946f-a0a8-43dc-acee-53fc5c09129e', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='e8096f063b567d87c66be4a39d33a8de5caab4efd44994aa71214b8be272fb9a'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='52564d79-539c-422f-9246-2d2c1794d537', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='95bd8f00efb6eac1032a4b5d520639c180efd51353a77922ae6e9fb87b4324e0'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='c6fbf5da-07b2-43d9-bb2d-f0b4779fb0db', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='4eb2a907e2244b993d4a587452b9964476bddc4ade98239ad2a42beb9497958f')}, text='The change began in England, where a \nseries of machines were invented and steam power \nreplaced water, wind, and animal power. These ad- \nvances gave British industry significant advantages \nover other nations, and England attempted to restrict \nexport of the new technologies. However, the revo- \nlution eventually spread to other European countries \nand the United States. Several inventions of the Indus- \ntrial Revolution greatly contributed to the development \nof manufacturing: (1) Watt’s steam engine—a new \npower-generating technology for industry; (2) machine \ntools, starting with John Wilkinson’s boring machine \naround 1775 (Historical Note 21.1); (3) the spinning \njenny, power loom, and other machinery for the tex- \ntile industry that permitted significant increases in \nproductivity; and (4) the factory system—a new way \nof organizing large numbers of production workers \nbased on division of labor. \nWhile England was leading the industrial revolu- \ntion, an important concept was being introduced in the \nUnited States: interchangeable parts manufacture. \nMuch credit for this concept is given to Eli Whitney \n(1765–1825), although its importance had been rec- \nognized by others [10].', mimetype='text/plain', start_char_idx=6172, end_char_idx=7377, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='c6fbf5da-07b2-43d9-bb2d-f0b4779fb0db', embedding=None, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='cc53946f-a0a8-43dc-acee-53fc5c09129e', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='e8096f063b567d87c66be4a39d33a8de5caab4efd44994aa71214b8be272fb9a'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='0d679692-dc49-4312-b8f3-2a2016ad671d', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='6aeffd27b1555b90085810b02d6a89430f6331cad9d134128f5757c55e17d7d7'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='5ee54590-ebf9-4056-9407-0f232e27a5b1', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='6a1c4cfd11de294d05d83368060e15f95545ce74a482a7224c1ccd5c5c04479c')}, text='While England was leading the industrial revolu- \ntion, an important concept was being introduced in the \nUnited States: interchangeable parts manufacture. \nMuch credit for this concept is given to Eli Whitney \n(1765–1825), although its importance had been rec- \nognized by others [10]. In 1797, Whitney negotiated \na contract to produce 10,000 muskets for the U.S. \ngovernment. The traditional way of making guns at the \ntime was to custom-fabricate each part for a par- ticular \ngun and then hand-fit the parts together by fil- ing. \nEach musket was unique, and the time to make it was \nconsiderable. Whitney believed that the com- ponents \ncould be made accurately enough to permit parts \nassembly without fitting. After several years of \ndevelopment in his Connecticut factory, he traveled to \nWashington in 1801 to demonstrate the principle. \nHe laid out components for 10 muskets before gov- \nernment officials, including Thomas Jefferson, and \nproceeded to select parts randomly to assemble the \nguns. No special filing or fitting was required, and \nall of the guns worked perfectly.', mimetype='text/plain', start_char_idx=7091, end_char_idx=8181, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='5ee54590-ebf9-4056-9407-0f232e27a5b1', embedding=None, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='cc53946f-a0a8-43dc-acee-53fc5c09129e', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='e8096f063b567d87c66be4a39d33a8de5caab4efd44994aa71214b8be272fb9a'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='c6fbf5da-07b2-43d9-bb2d-f0b4779fb0db', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='b5d760a0783b4ee89b1b42f72fb76bd559536170051e26c15aa9182194b55a1f'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='98f9a3ce-7fce-4fd9-80ee-2af4b82e87bf', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='72122cd392802aeb47a60088a3b37c7cf674a86837ba73a071271d8fa21ecafe')}, text='After several years of \ndevelopment in his Connecticut factory, he traveled to \nWashington in 1801 to demonstrate the principle. \nHe laid out components for 10 muskets before gov- \nernment officials, including Thomas Jefferson, and \nproceeded to select parts randomly to assemble the \nguns. No special filing or fitting was required, and \nall of the guns worked perfectly. The secret be- hind his \nachievement was the collection of special machines, \nfixtures, and gages that he had developed in \nhis \nfactory. Interchangeable parts manufacture \nrequired many years of development before becom- \ning a practical reality, but it revolutionized methods of \nmanufacturing. It is a prerequisite for mass produc- \ntion. Because its origins were in the United States, \ninterchangeable parts production came to be known as \nthe American System of manufacture. \nThe mid- and late 1800s witnessed the expan- sion \nof railroads, steam-powered ships, and other machines \nthat created a growing need for iron and steel. New \nsteel production methods were devel- oped to meet \nthis demand (Historical Note 6.1).', mimetype='text/plain', start_char_idx=7809, end_char_idx=8907, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='98f9a3ce-7fce-4fd9-80ee-2af4b82e87bf', embedding=None, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='cc53946f-a0a8-43dc-acee-53fc5c09129e', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='e8096f063b567d87c66be4a39d33a8de5caab4efd44994aa71214b8be272fb9a'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='5ee54590-ebf9-4056-9407-0f232e27a5b1', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='a834316b1184b683e6b4512587603277e6fee11514706a2d58f5ab36c99c4f6d'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='7cdb23f1-c9ab-4b0d-b6e5-162788a61797', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='a52a58f832c23fbf69a6c5cbee279d3352731988121b149c1c105d7937bb180c')}, text='Because its origins were in the United States, \ninterchangeable parts production came to be known as \nthe American System of manufacture. \nThe mid- and late 1800s witnessed the expan- sion \nof railroads, steam-powered ships, and other machines \nthat created a growing need for iron and steel. New \nsteel production methods were devel- oped to meet \nthis demand (Historical Note 6.1). Also during this \nperiod, several consumer products were developed, \nincluding \nthe \nsewing \nmachine, \nbicycle, \nand \nautomobile. To meet the mass demand for these \nproducts, more efficient production methods were \nrequired. Some historians identify developments dur- \ning this period as the Second Industrial Revolution, \ncharacterized in terms of its effects on manufacturing \nsystems by (1) mass production, (2) scientific manage- \nment movement, (3) assembly lines, and (4) electrifi- \ncation of factories. \nIn the late 1800s, the scientific management \nmovement was developing in the United States in \nresponse to the need to plan and control the activi- ties \nof growing numbers of production workers.', mimetype='text/plain', start_char_idx=8524, end_char_idx=9615, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='7cdb23f1-c9ab-4b0d-b6e5-162788a61797', embedding=None, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='cc53946f-a0a8-43dc-acee-53fc5c09129e', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='e8096f063b567d87c66be4a39d33a8de5caab4efd44994aa71214b8be272fb9a'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='98f9a3ce-7fce-4fd9-80ee-2af4b82e87bf', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='d35acc44b2096d0c3b1c9ae9b00af60469e017d7815586adaf4a730866f744ef'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='9a79522f-7b90-41d8-88e2-2181598c09d4', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='15fba74e314a1d6dc2f4601bc0e7264c2209e54773872878edfa4a8ebbccc891')}, text='In the late 1800s, the scientific management \nmovement was developing in the United States in \nresponse to the need to plan and control the activi- ties \nof growing numbers of production workers. The \nmovement’s leaders included Frederick W. Taylor \n(1856–1915), Frank Gilbreth (1868–1924), and his wife \nLillian (1878–1972). Scientific management included \nseveral features [3]: (1) motion study, aimed at find- \ning the best method to perform a given task; (2) time \nstudy, to establish work standards for a job; (3) exten- \nsive use of standards in industry; (4) the piece rate \nsystem and similar labor incentive plans; and (5) use \nof data collection, record keeping, and cost account- \ning in factory operations. \nHenry Ford (1863–1947) introduced the assembly \nline in 1913 at his Highland Park, Michigan plant. The \nassembly line made possible the mass production of \ncomplex consumer products. Use of assembly line \nmethods permitted Ford to sell a Model T automobile \nfor as little as $500, thus making ownership of cars \nfeasible for a large segment of the U.S. population.', mimetype='text/plain', start_char_idx=9420, end_char_idx=10504, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='9a79522f-7b90-41d8-88e2-2181598c09d4', embedding=None, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='cc53946f-a0a8-43dc-acee-53fc5c09129e', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='e8096f063b567d87c66be4a39d33a8de5caab4efd44994aa71214b8be272fb9a'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='7cdb23f1-c9ab-4b0d-b6e5-162788a61797', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='c2722e1455067bfa5b788427cb3e6cc9590e6fbc20c2356c23cdbed0b62c9549'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='1e140c74-efef-4c5e-bf3a-3ec3a6840b6d', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='8d07f605e127b93156dbd26ef8f4b35b77cf3f025978c5524df7d25c56377427')}, text='Henry Ford (1863–1947) introduced the assembly \nline in 1913 at his Highland Park, Michigan plant. The \nassembly line made possible the mass production of \ncomplex consumer products. Use of assembly line \nmethods permitted Ford to sell a Model T automobile \nfor as little as $500, thus making ownership of cars \nfeasible for a large segment of the U.S. population. \nIn 1881, the first electric power generating station \nhad been built in New York City, and soon electric mo- \ntors were being used as a power source to operate fac- \ntory machinery. This was a far more convenient power \ndelivery system than steam engines, which required \noverhead belts to distribute power to the machines. By \n1920, electricity had overtaken steam as the principal \npower source in U.S. factories. The twentieth century \nwas a time of more technological advances than in all \nother centuries combined. Many of these develop- \nments resulted in the automation of manufacturing. \nSection 1.1/What Is Manufacturing?', mimetype='text/plain', start_char_idx=10140, end_char_idx=11136, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='1e140c74-efef-4c5e-bf3a-3ec3a6840b6d', embedding=None, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='cc53946f-a0a8-43dc-acee-53fc5c09129e', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='e8096f063b567d87c66be4a39d33a8de5caab4efd44994aa71214b8be272fb9a'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='9a79522f-7b90-41d8-88e2-2181598c09d4', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='0e57ddef8c1d2a82c68bbc2be20ef4aebca2836b56ea7470c97999c7952bc44e'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='b9fe8ae7-98c9-48c7-823c-c95d8aacf12b', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='832b57608badd3454696053355065725939b9f84215ebdfc87d1a6c7ca4e5e94')}, text='This was a far more convenient power \ndelivery system than steam engines, which required \noverhead belts to distribute power to the machines. By \n1920, electricity had overtaken steam as the principal \npower source in U.S. factories. The twentieth century \nwas a time of more technological advances than in all \nother centuries combined. Many of these develop- \nments resulted in the automation of manufacturing. \nSection 1.1/What Is Manufacturing? \n4 \n \n \n \n \nScrap and \nwaste \nManufacturing \nprocess \n \n \n \n \n \nStarting \nmaterial \nProcessed \npart \n$ \n \n$$$ \n \n \n \n \nStarting \nmaterial \nMaterial in \nprocessing \nProcessed \npart \n \n(a) \n(b) \n \nFIGURE 1.1  Two ways to define manufacturing: (a) as a technical process, and (b) as an economic process. \n \n \n1.1.1 MANUFACTURING DEFINED \n \nAs a field of study in the modern context, manufacturing can be defined two ways, \none technologic, and the other economic. Technologically, manufacturing is the ap- \nplication of physical and chemical processes to alter the geometry, properties, and/ \nor appearance of a given starting material to make parts or products; manufacturing \nalso includes assembly of multiple parts to make products.', mimetype='text/plain', start_char_idx=10688, end_char_idx=11870, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
# ...
#  TextNode(id_='5684f2b5-0529-4c62-b5f6-86d91938129f', embedding=None, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='cc53946f-a0a8-43dc-acee-53fc5c09129e', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='e8096f063b567d87c66be4a39d33a8de5caab4efd44994aa71214b8be272fb9a'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='51d58357-888f-4e70-829a-6048a9a5526d', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='33cafab977b6d1ac1b80b24f7a3967f4b2cfd812b8d66204cd903c5216cb7c13'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='b992946a-20be-4adb-aaa4-3346e9de423e', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='cda7a09fc096cb094f79d04dc7a6a9e5310a0a11d6572e477e6701fd3809c83b')}, text='This crystal structure is much more \ncompact than the random and loosely packed liquid from which it formed. Thus, \nthe process of solidification produces the abrupt volumetric contraction observed \nin Figure 2.15 for the crystalline material. By contrast, amorphous materials do not \nachieve this repeating and closely packed structure at low temperatures. The atomic \nstructure is the same random arrangement as in the liquid state; thus, there is no \nabrupt volumetric change as these materials transition from liquid to solid. \n \nEngineering Materials \nThis section summarizes how atomic structure, bonding, and crystal structure (or \nabsence thereof) are related to the type of engineering material: metals, ceramics, \nand polymers. \n \nMetals Metals have crystalline structures in the solid state, almost without excep- \ntion. The unit cells of these crystal structures are almost always BCC, FCC, or HCP. \nThe atoms of the metals are held together by metallic bonding, which means that \ntheir valence electrons can move about with relative freedom (compared with the \nother types of atomic and molecular bonding). These structures and bonding gener- \nally make the metals strong and hard.', mimetype='text/plain', start_char_idx=132452, end_char_idx=133646, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='b992946a-20be-4adb-aaa4-3346e9de423e', embedding=None, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='cc53946f-a0a8-43dc-acee-53fc5c09129e', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='e8096f063b567d87c66be4a39d33a8de5caab4efd44994aa71214b8be272fb9a'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='5684f2b5-0529-4c62-b5f6-86d91938129f', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='79bd5f41edd2642bab32d403af4549550cd1c0fb7bc13d7672cd9c75021911d0'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='917c1867-8e0f-45af-8307-d6d15f78c670', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='c686a67a1261900652407cf3390ca2548a23d7feec5a0e84efa37ce60d6ff171')}, text='Metals Metals have crystalline structures in the solid state, almost without excep- \ntion. The unit cells of these crystal structures are almost always BCC, FCC, or HCP. \nThe atoms of the metals are held together by metallic bonding, which means that \ntheir valence electrons can move about with relative freedom (compared with the \nother types of atomic and molecular bonding). These structures and bonding gener- \nally make the metals strong and hard. Many of the metals are quite ductile (capable of being \ndeformed, which is useful in manufacturing), especially the FCC metals. Other general \nproperties of metals related to structure and bonding include high electri- cal and \nthermal conductivity, opaqueness (impervious to light rays), and reflectivity \n(capacity to reflect light rays). \n \nCeramics Ceramic molecules are characterized by ionic or covalent bonding, or \nboth. The metallic atoms release or share their outermost electrons to the nonme- \ntallic atoms, and a strong attractive force exists within the molecules. The general \nproperties that result from these bonding mechanisms include high hardness and \nstiffness (even at elevated temperatures) and brittleness (no ductility).', mimetype='text/plain', start_char_idx=133193, end_char_idx=134392, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='917c1867-8e0f-45af-8307-d6d15f78c670', embedding=None, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='cc53946f-a0a8-43dc-acee-53fc5c09129e', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='e8096f063b567d87c66be4a39d33a8de5caab4efd44994aa71214b8be272fb9a'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='b992946a-20be-4adb-aaa4-3346e9de423e', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='2e5d131f875cf6dfa6f96ae8bbac70e1938d9ffad154bc69eed35f6321642a5d'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='045d1d3e-019d-4dbb-ad11-32fa3d409d82', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='740ae9df403f0672374b8bdb3b0c6e6ec78f290abfa518575a6f20986e7c5f2f')}, text='Ceramics Ceramic molecules are characterized by ionic or covalent bonding, or \nboth. The metallic atoms release or share their outermost electrons to the nonme- \ntallic atoms, and a strong attractive force exists within the molecules. The general \nproperties that result from these bonding mechanisms include high hardness and \nstiffness (even at elevated temperatures) and brittleness (no ductility). The bond- \ning also means that ceramics are electrically insulating (nonconducting), refractory \n(thermally resistant), and chemically inert. \n2.5 \nSection 1.6/Recent Developments in Manufacturing \n50 \n \n \nCeramics possess either a crystalline or noncrystalline \nstructure. Most ceramics have a crystal structure, whereas glasses \nbased on silica (SiO2) are amorphous. In certain cases, either \nstructure can exist in the same ceramic material. For example, \nsilica occurs in nature as crystalline quartz. When this mineral is \nmelted and then cooled, it solidifies to form fused silica, which \nhas a noncrystalline structure. \n \nPolymers A polymer molecule consists of many repeating \nmers to form very large molecules held together by covalent \nbonding.', mimetype='text/plain', start_char_idx=133991, end_char_idx=135148, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='045d1d3e-019d-4dbb-ad11-32fa3d409d82', embedding=None, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='cc53946f-a0a8-43dc-acee-53fc5c09129e', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='e8096f063b567d87c66be4a39d33a8de5caab4efd44994aa71214b8be272fb9a'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='917c1867-8e0f-45af-8307-d6d15f78c670', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='789dc996b2fecd9ddc66838ae25ade1afddc0b53e5c4baded54e06c826ec25e3'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='726d77a4-a90b-458d-8f08-535084788053', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='34fa5d5fff41d4fb678209cc36dcf453e348736f15c9c6d1ee6c0775ca89fd7b')}, text='In certain cases, either \nstructure can exist in the same ceramic material. For example, \nsilica occurs in nature as crystalline quartz. When this mineral is \nmelted and then cooled, it solidifies to form fused silica, which \nhas a noncrystalline structure. \n \nPolymers A polymer molecule consists of many repeating \nmers to form very large molecules held together by covalent \nbonding. Elements in polymers are usu- ally carbon plus one or \nmore other elements such as hydrogen, nitrogen, oxygen, and \nchlorine. Secondary bonding (van der Waals) holds the \nmolecules \ntogether \nwithin \nthe \naggregate \nmaterial \n(intermolecular bonding). Polymers have either a glassy \nstructure or mixture of glassy and crystalline. There are \ndifferences among the three polymer types. In thermoplastic \npolymers, the molecules consist of long chains of mers in a \nlinear structure. These materials can be heated and cooled \nwithout substantially altering their linear structure. In \nthermosetting polymers, the molecules transform into a rigid, \nthree-dimensional structure on cooling from a heated plastic \ncondition.', mimetype='text/plain', start_char_idx=134762, end_char_idx=135867, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='726d77a4-a90b-458d-8f08-535084788053', embedding=None, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='cc53946f-a0a8-43dc-acee-53fc5c09129e', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='e8096f063b567d87c66be4a39d33a8de5caab4efd44994aa71214b8be272fb9a'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='045d1d3e-019d-4dbb-ad11-32fa3d409d82', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='95972364b7bc79d766e59d5cba98160da4a54878bee905a20fca13a6da5c69a4')}, text='There are \ndifferences among the three polymer types. In thermoplastic \npolymers, the molecules consist of long chains of mers in a \nlinear structure. These materials can be heated and cooled \nwithout substantially altering their linear structure. In \nthermosetting polymers, the molecules transform into a rigid, \nthree-dimensional structure on cooling from a heated plastic \ncondition. If thermosetting polymers are reheated, they \ndegrade chemically rather than soften. Elastomers have large \nmolecules with coiled struc- tures. The uncoiling and recoiling \nof the molecules when subjected to stress cycles motivate the \naggregate material to exhibit its characteristic elastic behavior. \nThe molecular structure and bonding of polymers provide them \nwith the fol- lowing typical properties: low density, high \nelectrical resistivity (some polymers are used as insulating \nmaterials), and low thermal conductivity. Strength and stiff- ness \nof polymers vary widely. Some are strong and rigid (although \nnot matching the strength and stiffness of metals or ceramics), \nwhereas others exhibit highly elastic behavior.', mimetype='text/plain', start_char_idx=135480, end_char_idx=136598, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')]

# %%
print(len(documents))
print(len(nodes))
# Out:
# 1
# 177

# %% [markdown]
# ## Single result test

# %%
retriever = index.as_retriever()

# %%
retriever.retrieve("noncrystalline structure")
# Out:
# [NodeWithScore(node=TextNode(id_='b30af281-c625-4c31-a03b-872829a3ac79', embedding=None, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='0c20e6ff-0d16-4336-8785-d5fb64141c74', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='e8096f063b567d87c66be4a39d33a8de5caab4efd44994aa71214b8be272fb9a'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='cdd7f7aa-e043-488f-8942-287fd0df3a4f', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='0f4537a43e46292de3825f065d0f016353e62535f839face4b64491cd01b89a1'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='ca83a1d4-9435-4386-8e46-a9ec04d1519c', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='8e5ff062087839bf0dc7461557027c188af60c4c1a672bddb2aa9fdc00b1d46b')}, text='The pattern may be replicated millions of times within \n2.3 \nSection 2.3/Crystalline Structures \n42 \n \n \n \nFIGURE 2.7 Body-centered cubic (BCC) crystal structure: (a) unit cell with atoms \nindicated as point locations in a three-dimensional axis system; (b) unit cell model \nshowing closely packed atoms (sometimes called the hard-ball model); and \n(c) repeated pattern of the BCC structure. \n \na given crystal. The structure can be viewed in the form of a unit cell, which is the \nbasic geometric grouping of atoms that is repeated. To illustrate, consider the unit \ncell for the body-centered cubic (BCC) crystal structure shown in Figure 2.7, one of \nthe common structures found in metals. The simplest model of the BCC unit cell is \nillustrated in Figure 2.7(a). Although this model clearly depicts the locations of the \natoms within the cell, it does not indicate the close packing of the atoms that occurs \nin the real crystal, as in Figure 2.7(b). Figure 2.7(c) shows the repeating nature of the unit \ncell within the crystal. \n \n \n2.3.1 TYPES OF CRYSTAL STRUCTURES \n \nIn metals, three lattice structures are common: (1) body-centered cubic (BCC), \n(2) face-centered cubic (FCC), and (3) hexagonal close-packed (HCP), illustrated \nin Figure 2.8. Crystal structures for the common metals are presented in Table 2.1. \nIt should be noted that some metals undergo a change of structure at different \ntemperatures. Iron, for example, is BCC at room temperature; it changes to FCC \nabove 912°C (1674°F) and back to BCC at temperatures above 1400°C (2550°F). \nWhen a metal (or other material) changes structure like this, it is referred to as \nbeing allotropic. \n \n \nFIGURE 2.8 Three types of crystal structures in metals: (a) body-centered cubic, (b) face-centered \ncubic, and (c) hexagonal close-packed. \nSection 2.3/Crystalline Structures \n43 \n \n \n TABLE • 2.1 Crystal structures for the common metals (at room temperature). \n \nBody-Centered Cubic \nFace-Centered Cubic \nHexagonal Close-Packed \n(BCC) \n \n(FCC) \n \n(HCP) \nChromium (Cr) \nAluminum (Al) \nMagnesium (Mg) \nIron (Fe) \nCopper (Cu) \nTitanium (Ti) \nMolybdenum (Mo) \nGold (Au) \nZinc (Zn) \nTantalum (Ta) \nLead (Pb) \nTungs ...
#  NodeWithScore(node=TextNode(id_='6fa640cd-1b38-43ac-b5bc-8d2e8ee210d9', embedding=None, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='0c20e6ff-0d16-4336-8785-d5fb64141c74', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='e8096f063b567d87c66be4a39d33a8de5caab4efd44994aa71214b8be272fb9a'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='90b3fafa-9206-41fe-a4f7-9328c40c357e', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/input/Sec124.txt', 'file_name': 'Sec124.txt', 'file_type': 'text/plain', 'file_size': 136812, 'creation_date': '2024-07-19', 'last_modified_date': '2024-07-19'}, hash='4a544c8e6282db8fd5a0375486a0fdf4062336444ca6b56159a593106d2ec138'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='a6939108-5828-4346-8c9f-0c01763580f3', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='c3541341f7a7bccde52b741e504a1ac42a561e3c070bb2bc2b5dc612808c37de')}, text='The current chapter considers the \natomic structure of matter and the bonding bet- ween \natoms and molecules. It also shows how atoms and \nmolecules in engineering materials organize themselves \ninto two structural forms: crystalline and noncrystalline. \nIt turns out that the basic engineering materials—metals, \nceramics, and polymers—can exist in either form, \nalthough a preference for a particular form is usually \nexhibited by a given material. For exam- ple, metals \nalmost always exist as crystals in their solid state. Glass \n(e.g., window glass), a ceramic, assumes a noncrystalline \nform. Some polymers are mixtures of crystalline and \namorphous structures. \nChapters 3 and 4 discuss the mechanical and physical \nproperties that are relevant in manufacturing. Of course, \nthese properties are also important in product design. \nChapter 5 is concerned with several part and product \n2 \n \n2.1\nAtomic Structure and the Elements \n2.2\nBonding between Atoms and Molecules \n2.3\nCrystalline Structures \n2.3.1\n \n2.3.2\n \n2.3.3\n \n2.3.4\n \n2.4\nNoncrystalline (Amorphous) Structures \n2.5\nEngineering Materials \n36 \nSection 2.1/Atomic Structure and the Elements \n37 \n \n \nattributes that are specified during product design and must be achieved in manufac- turing: \ndimensions, tolerances, and surface finish. Chapter 5 also describes how these attributes \nare measured. \n \nAtomic Structure and the Elements \nThe basic structural unit of matter is the atom. Each atom is composed of a positively \ncharged nucleus, surrounded by a sufficient number of negatively charged electrons so that \nthe charges are balanced. The number of electrons identifies the atomic number and \nthe element of the atom. There are slightly more than 100 elements (not counting a few \nextras that have been artificially synthesized), and these elements are the chemi- cal \nbuilding blocks of all matter. \nJust as there are differences among the elements, there are also similarities. The \nelements can be grouped into families and relationships established between and \nwithin the families by means of the Periodic Table, shown in Figure 2.1. In the \nhorizontal direction there is a certain repetition, or perio ...

# %%
llm = OpenAI(model="gpt-4o")
query_engine = index.as_query_engine(llm=llm)

# %%
query_engine.query("Define manufacturing.")

# %%
prompts_dict = query_engine.get_prompts()
print(prompts_dict)
# Out:
# {'response_synthesizer:text_qa_template': SelectorPromptTemplate(metadata={'prompt_type': <PromptType.QUESTION_ANSWER: 'text_qa'>}, template_vars=['context_str', 'query_str'], kwargs={}, output_parser=None, template_var_mappings={}, function_mappings={}, default_template=PromptTemplate(metadata={'prompt_type': <PromptType.QUESTION_ANSWER: 'text_qa'>}, template_vars=['context_str', 'query_str'], kwargs={}, output_parser=None, template_var_mappings=None, function_mappings=None, template='Context information is below.\n---------------------\n{context_str}\n---------------------\nGiven the context information and not prior knowledge, answer the query.\nQuery: {query_str}\nAnswer: '), conditionals=[(<function is_chat_model at 0x7f80eec532e0>, ChatPromptTemplate(metadata={'prompt_type': <PromptType.CUSTOM: 'custom'>}, template_vars=['context_str', 'query_str'], kwargs={}, output_parser=None, template_var_mappings=None, function_mappings=None, message_templates=[ChatMessage(role=<MessageRole.SYSTEM: 'system'>, content="You are an expert Q&A system that is trusted around the world.\nAlways answer the query using the provided context information, and not prior knowledge.\nSome rules to follow:\n1. Never directly reference the given context in your answer.\n2. Avoid statements like 'Based on the context, ...' or 'The context information ...' or anything along those lines.", additional_kwargs={}), ChatMessage(role=<MessageRole.USER: 'user'>, content='Context information is below.\n---------------------\n{context_str}\n---------------------\nGiven the context information and not prior knowledge, answer the query.\nQuery: {query_str}\nAnswer: ', additional_kwargs={})]))]), 'response_synthesizer:refine_template': SelectorPromptTemplate(metadata={'prompt_type': <PromptType.REFINE: 'refine'>}, template_vars=['query_str', 'existing_answer', 'context_msg'], kwargs={}, output_parser=None, template_var_mappings={}, function_mappings={}, default_template=PromptTemplate(metadata={'prompt_type': <PromptType.REFINE: 'refine'>}, template_vars=['query_str', 'existing_answer', 'context_msg'], kwargs={}, output_parser=None, template_var_mappings=None, function_mappings=None, template="The original query is as follows: {query_str}\nWe have provided an existing answer: {existing_answer}\nWe have the opportunity to refine the existing answer (only if needed) with some more context below.\n------------\n{context_msg}\n------------\nGiven the new context, refine the original answer to better answer the query. If the context isn't useful, return the original answer.\nRefined Answer: "), conditionals=[(<function is_chat_model at 0x7f80eec532e0>, ChatPromptTemplate(metadata={'prompt_type': <PromptType.CUSTOM: 'custom'>}, template_vars=['context_msg', 'query_str', 'existing_answer'], kwargs={}, output_parser=None, template_var_mappings=None, function_mappings=None, message_templates=[ChatMessage(role=<MessageRole.USER: 'user'>, content="You are an expert Q&A system that strictly operates in two modes when refining existing answers:\n1. **Rewrite** an original answer using the new context.\n2. **Repeat** the original answer if the new context isn't useful.\nNever reference the original answer or context directly in your answer.\nWhen in doubt, just repeat the original answer.\nNew Context: {context_msg}\nQuery: {query_str}\nOriginal Answer: {existing_answer}\nNew Answer: ", additional_kwargs={})]))])}

# %% [markdown]
# ## Continue

# %%
from llama_index.core import PromptTemplate


new_summary_tmpl_str = (
    "Answer the question based only on the following context:\n"
    "{context_str}\n"
    "Answer the following question:"
    "Query: {query_str}\n"
    "Answer: "
)
new_summary_tmpl = PromptTemplate(new_summary_tmpl_str)

# %%
query_engine.update_prompts(
    {"response_synthesizer:text_qa_template": new_summary_tmpl}
)

# %%
prompts_dict = query_engine.get_prompts()
print(prompts_dict)
# Out:
# {'response_synthesizer:text_qa_template': PromptTemplate(metadata={'prompt_type': <PromptType.CUSTOM: 'custom'>}, template_vars=['context_str', 'query_str'], kwargs={}, output_parser=None, template_var_mappings=None, function_mappings=None, template='Answer the question based only on the following context:\n{context_str}\nAnswer the following question:Query: {query_str}\nAnswer: '), 'response_synthesizer:refine_template': SelectorPromptTemplate(metadata={'prompt_type': <PromptType.REFINE: 'refine'>}, template_vars=['query_str', 'existing_answer', 'context_msg'], kwargs={}, output_parser=None, template_var_mappings={}, function_mappings={}, default_template=PromptTemplate(metadata={'prompt_type': <PromptType.REFINE: 'refine'>}, template_vars=['query_str', 'existing_answer', 'context_msg'], kwargs={}, output_parser=None, template_var_mappings=None, function_mappings=None, template="The original query is as follows: {query_str}\nWe have provided an existing answer: {existing_answer}\nWe have the opportunity to refine the existing answer (only if needed) with some more context below.\n------------\n{context_msg}\n------------\nGiven the new context, refine the original answer to better answer the query. If the context isn't useful, return the original answer.\nRefined Answer: "), conditionals=[(<function is_chat_model at 0x72f64646b380>, ChatPromptTemplate(metadata={'prompt_type': <PromptType.CUSTOM: 'custom'>}, template_vars=['context_msg', 'query_str', 'existing_answer'], kwargs={}, output_parser=None, template_var_mappings=None, function_mappings=None, message_templates=[ChatMessage(role=<MessageRole.USER: 'user'>, content="You are an expert Q&A system that strictly operates in two modes when refining existing answers:\n1. **Rewrite** an original answer using the new context.\n2. **Repeat** the original answer if the new context isn't useful.\nNever reference the original answer or context directly in your answer.\nWhen in doubt, just repeat the original answer.\nNew Context: {context_msg}\nQuery: {query_str}\nOriginal Answer: {existing_answer}\nNew Answer: ", additional_kwargs={})]))])}

# %%
## Single Test
result = query_engine.query("Define manufacturing.")

# %%
import pandas as pd

# Define the file path
csv_file_path = '/home/zihan/Desktop/Manufacturing_QA/Experimental_and_Test/GraphRag/TestResult.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)
questions = df['Question'].tolist()
results = []
for question in questions:
    result = query_engine.query(question)
    print(result)
    results.append(result.response)

Outputs_df = pd.DataFrame(results, columns=['LangChain'])
Outputs_df
# Out:
# The elements listed in the Periodic Table can be divided into three categories: metals, nonmetals, and metalloids (or semimetals). Examples of each category are:
#
# - Metals: Iron (Fe)
# - Nonmetals: Nitrogen (N)
# - Metalloids (or Semimetals): Silicon (Si)
# Some materials that possess a noncrystalline structure include glass (e.g., window glass) and fused silica.
# The noble metals are copper, silver, and gold.
# Primary bonding involves strong atom-to-atom attractions that include the exchange or sharing of valence electrons, forming bonds such as ionic, covalent, and metallic. These bonds are generally associated with the formation of molecules and are much stronger than secondary bonds. In contrast, secondary bonding involves attraction forces between molecules (intermolecular forces) without the transfer or sharing of electrons, making these bonds weaker. Examples of secondary bonding include dipole forces, London forces, and hydrogen bonding.
# Ionic bonding works by the transfer of electrons from atoms of one element to atoms of another element. Specifically, the atoms of one element give up their outer electron(s), which are then attracted to the atoms of another element to increase their electron count in the outermost shell to eight, achieving a stable atomic configuration. This transfer of electrons results in the formation of ions, which are atoms with a net electric charge due to the loss or gain of electrons. The electrostatic attraction between the positively charged ions (cations) and negatively charged ions (anions) forms a strong bond, known as an ionic bond. An example of ionic bonding is the formation of sodium fluoride (NaF) from sodium (Na) and fluorine (F), where sodium donates an electron to fluorine, resulting in the formation of Na+ and F- ions. Properties of materials with ionic bonding include low electrical conductivity and poor ductility.
# Crystalline structures in materials are characterized by a highly ordered arrangement of atoms or molecules in a repeating pattern, forming a crystal lattice. This orderliness results in distinct unit cells, such as BCC (Body-Centered Cubic), FCC (Face-Centered Cubic), or HCP (Hexagonal Close-Packed) structures, which are typical in metals. Crystalline materials exhibit properties such as high strength, hardness, and, in the case of metals, ductility and high electrical and thermal conductivity.
#
# Noncrystalline (or amorphous) structures, on the other hand, lack this long-range order. The atoms or molecules are arranged more randomly, without a repeating pattern. This structure is common in materials like glass (a type of ceramic) and certain polymers. Noncrystalline materials tend to be less rigid and more brittle compared to their crystalline counterparts. They also exhibit different thermal and electrical properties, often being insulating and less thermally conductive.
# Some common point defects in a crystal lattice structure include:
#
# 1. Vacancy: A missing atom within the lattice structure.
# 2. Ion-pair vacancy (Schottky defect): A missing pair of ions of opposite charge in a compound that maintains an overall charge balance.
# 3. Interstitialcy: A lattice distortion produced by the presence of an extra atom in the structure.
# 4. Displaced ion (Frenkel defect): Occurs when an ion is removed from its regular position in the lattice structure and inserted into an interstitial position not normally occupied by such an ion.
# Elastic deformation in a crystal lattice structure involves a temporary tilting of the lattice without any permanent changes in the positions of the atoms. When the applied mechanical stress is removed, the lattice structure returns to its original shape. In contrast, plastic deformation results in a permanent shape change where the atoms in the lattice move from their previous locations to form a new equilibrium lattice. This permanent movement of atoms means that the lattice does not return to its original shape even after the stress is removed.
# Grain boundaries contribute to the strain hardening phenomenon in metals by interrupting the continued movement of dislocations. This interference with dislocation movement increases the strength of the metal as it is deformed.
# Some materials that have a crystalline structure include metals (which almost always exist as crystals in their solid state) and most ceramics. For example, silica occurs in nature as crystalline quartz.
# Manufacturing is the process of producing hardware, which ranges from nuts and bolts to digital computers and military weapons. It involves the conversion of raw materials into finished products through various processes and technologies. Manufacturing is a critical commercial activity performed by companies that sell products to customers, and it is a principal activity in secondary industries. The term is derived from the Latin words "manus" (hand) and "factus" (make), originally meaning "made by hand," but today it encompasses automated and computer-controlled machinery.
# The provided context does not explicitly define the difference between thermoplastic polymers and thermosetting polymers. However, based on general knowledge, the difference can be summarized as follows:
#
# Thermoplastic polymers can be melted and reshaped multiple times without undergoing any significant chemical change. They become soft when heated and harden upon cooling. Examples include polyethylene and polyvinylchloride.
#
# Thermosetting polymers, on the other hand, undergo a chemical change when they are first heated and molded, which makes them set into a permanent shape. Once set, they cannot be remelted or reshaped. Examples include Bakelite and epoxy resins.
# A unit operation is defined as a single step in the sequence of steps required to make the final product. The cycle time of a unit operation is the time that one work unit spends being processed or assembled, which includes the time interval between when one work unit begins the operation and the next unit begins. It typically consists of the actual processing time plus the work handling time, and in some processes, it also includes the time required to periodically change the tooling used in the operation when it wears out.
# In manufacturing processes, a processing operation uses energy to alter a work part’s shape, physical properties, or appearance to add value to the material. This involves applying mechanical, thermal, electrical, or chemical energy in a controlled way by means of machinery and tooling. On the other hand, an assembly operation involves putting together multiple components to create a final product. The context provided does not explicitly define assembly operations, but it focuses on processing operations which include shaping, property-enhancing, and surface processing operations.
# The four categories of shaping operations are:
#
# 1. **Solidification processes**: The starting material is a heated liquid or semifluid that cools and solidifies to form the part geometry.
# 2. **Particulate processing**: The starting material is a powder, and the powders are formed and heated into the desired geometry.
# 3. **Deformation processes**: The starting material is a ductile solid (commonly metal) that is deformed to shape the part.
# 4. **Material removal processes**: The starting material is a solid (ductile or brittle), from which material is removed so that the resulting part has the desired geometry.
# Net shape processes are manufacturing methods that transform nearly all of the starting material into the final product, requiring no subsequent machining to achieve the final part geometry. In contrast, near net shape processes are those that require minimal machining to produce the final shape.
# The four types of permanent joining processes used in assembly are welding, brazing, soldering, and adhesive bonding.
# A machine tool is a type of production equipment used to make parts for consumer products and components for other production machines. It is considered the mother of all machinery in both a historic and reproductive sense.
# Special purpose production equipment is designed to produce a specific part or product in very large quantities. It is typically used for mass production, where the economics justify large investments to achieve high efficiencies and short cycle times. This equipment is often unique to the process and may not be commercially available, leading some companies to develop their own special purpose equipment. The tooling for special purpose machines is often an integral part of the machine and may not need changing except for replacement or repair.
#
# General purpose production equipment, on the other hand, is more flexible and adaptable to a variety of jobs. It is commercially available for any manufacturing company to invest in. The tooling used with general purpose equipment is designed to be exchanged for different work part types, allowing the equipment to be used for various production runs.
# Batch production is a manufacturing approach where a batch of one product is made, after which the manufacturing equipment is changed over to produce a batch of the next product, and so on. This method is often used for medium-quantity production (100–10,000 units annually) because the production rate of the equipment is greater than the demand rate for any single product type. This allows the same equipment to be shared among multiple products. However, the changeover between production runs takes time, which is a disadvantage as this setup time is lost production time. Batch production is commonly used for make-to-stock situations, where items are manufactured to replenish inventory that has been gradually depleted by demand. The equipment in batch production is usually arranged in a process layout.
# A process layout and a product layout differ primarily in how equipment and workstations are arranged and how work units move through the production facility:
#
# 1. **Process Layout**:
#    - **Arrangement**: Equipment is arranged according to function or type. For example, lathes are in one department, milling machines in another, and so on.
#    - **Flexibility**: Noted for its flexibility, it can accommodate a variety of operation sequences for different part configurations.
#    - **Operation Sequence**: Different parts, each requiring a different operation sequence, are routed through the departments in the particular order needed for their processing, usually in batches.
#    - **Efficiency**: The machinery and methods to produce a part are not designed for high efficiency.
#
# 2. **Product Layout**:
#    - **Arrangement**: Workstations and equipment are arranged in sequence, typically into one long line or a series of connected line segments.
#    - **Efficiency**: Designed specifically for the product to maximize efficiency.
#    - **Operation Sequence**: The work units are physically moved through the sequence to complete the product, often using mechanized conveyors.
#    - **Example**: The most familiar example is the assembly line, where each station completes a small amount of the total work on each unit of product.
#
# In summary, a process layout is organized by function and is flexible but less efficient, while a product layout is organized by the sequence of operations for a specific product and is highly efficient.
# Primary, secondary, and tertiary industries differ in their roles and the types of activities they perform:
#
# 1. **Primary Industries**: These industries cultivate and exploit natural resources. Examples include agriculture, forestry, fishing, livestock, quarries, and mining.
#
# 2. **Secondary Industries**: These industries take the outputs of the primary industries and convert them into consumer and capital goods. Manufacturing is the principal activity in this category. Examples include aerospace, food processing, apparel, glass and ceramics, automotive, heavy machinery, basic metals, paper, beverages, petroleum refining, building materials, pharmaceuticals, chemicals, plastics (shaping), computers, power utilities, construction, publishing, consumer appliances, textiles, electronics, tire and rubber, equipment, wood and furniture, and fabricated metals.
#
# 3. **Tertiary Industries**: These industries constitute the service sector of the economy. Examples include banking, insurance, communications, legal services, education, real estate, entertainment, repair and maintenance, government, restaurants, health and medical services, retail trade, hotels, tourism, information services, transportation, and wholesale trade.
# Two departments that are typically classified as manufacturing support departments are:
#
# 1. Quality control systems
# 2. Manufacturing support systems
# Overhead costs in a manufacturing company consist of all the expenses of operating the company other than material, labor, and equipment. They can be divided into two categories:
#
# 1. **Factory Overhead**: This includes the costs of running the factory excluding materials, direct labor, and equipment. Examples of factory overhead costs are:
#    - Plant supervision
#    - Maintenance
#    - Insurance
#    - Heat and light
#
# 2. **Corporate Overhead**: These are company expenses not directly related to the factory. Examples of corporate overhead costs are:
#    - Sales
#    - Marketing
#    - Accounting
#    - Legal
#    - Engineering
#    - Research and development
#    - Office space
#    - Utilities
#    - Health benefits
#
# These overhead costs are necessary for the company’s operations but are not directly tied to the manufacturing process. For pricing the product, these costs must be included to ensure the company does not lose money on each product sold.
# The two categories of overhead costs in a manufacturing company are:
#
# 1. **Factory Overhead**: This consists of the costs of running the factory excluding materials, direct labor, and equipment. It includes expenses such as plant supervision, maintenance, insurance, heat, and light.
#
# 2. **Corporate Overhead**: This consists of company expenses not related to the factory, such as sales, marketing, accounting, legal, engineering, research and development, office space, utilities, and health benefits. These functions are required in the company but are not directly related to the cost of manufacturing.
# Fixed costs, such as the cost of production equipment, remain constant regardless of the level of production output. They are capital investments made with the expectation that they will generate a revenue stream that exceeds their cost over time. These costs are paid upfront and amortized over the equipment's lifetime.
#
# Variable costs, on the other hand, fluctuate with the level of production. They include direct labor and material costs, which are incurred as they are used. Direct labor cost is measured per time unit (e.g., $/min), and material cost is measured per piece (e.g., $/pc).
# The term "availability" is not explicitly defined in the provided context. However, based on the context, it can be inferred that "availability" refers to the available labor hours of productive capacity in a machine shop that produces a variety of parts. This implies the measure of how much productive capacity is accessible or usable within a given time period.
# Consumer goods are products purchased directly by consumers for personal use, such as cars, personal computers, TVs, tires, and tennis rackets. Capital goods, on the other hand, are purchased by companies to produce goods and/or provide services. Examples of capital goods include aircraft, computers, communication equipment, medical apparatus, trucks and buses, railroad locomotives, machine tools, and construction equipment.
# Soft product variety occurs when there are only small differences among products, such as the differences among car models made on the same production line. In an assembled product, soft variety is characterized by a high proportion of common parts among the models. Hard product variety occurs when the products differ substantially, and there are few common parts, if any. The difference between a car and a truck exemplifies hard variety.
# There is an inverse correlation between product variety and production quantity in terms of factory operations. If a factory’s product variety is high, then its production quantity is likely to be low; but if production quantity is high, then product variety will be low.
# Technological processing capability refers to the available set of manufacturing processes that a plant or company can perform. It includes not only the physical processes but also the expertise possessed by plant personnel in these processing technologies. This capability is closely related to the material types that the processes can handle, meaning that by specializing in certain processes, a plant simultaneously specializes in certain material types. Companies must focus on designing and manufacturing products that are compatible with their technological processing capability.
# The four categories of engineering materials used in manufacturing are:
#
# 1. Metals
# 2. Ceramics
# 3. Polymers
# 4. Composites
# Steel can be defined as an iron–carbon alloy containing 0.02% to 2.11% carbon.
# Applications of steel include construction (bridges, I-beams, and nails), transportation (trucks, rails, and rolling stock for railroads), and consumer products (automobiles and appliances).
# Density, as a material property, refers to the mass per unit volume of a material. It is an important characteristic that can influence various mechanical properties and behaviors of materials. For example, in the context of crystalline and noncrystalline materials, density can change with the state of the material (solid or liquid) and its atomic arrangement. Crystalline materials typically have a denser, more closely packed structure compared to noncrystalline materials, which have a more loosely packed and random arrangement of atoms.
# The provided context does not define or mention dielectric strength as a material property.
# The provided context does not contain information about what an electrolyte is.
# The provided context does not explicitly discuss the melting characteristics of metal alloys. It primarily focuses on the melting characteristics of pure metals and amorphous materials. Therefore, based on the given context, the difference in melting characteristics between a pure metal element and a metal alloy cannot be determined.
# The melting characteristics of a noncrystalline material such as glass differ significantly from those of a pure metal. When glass transitions from the solid to the liquid state, it does not exhibit the sudden volumetric change characteristic of crystalline materials. Instead, as glass cools from a high-temperature liquid state, it gradually transforms into a solid through a transition phase called a supercooled liquid. During this phase, the material becomes increasingly viscous as the temperature decreases. Glass passes through its melting temperature \( T_m \) without a change in its thermal expansion slope. Eventually, a point is reached where the supercooled liquid converts to a solid, known as the glass-transition temperature \( T_g \). At this point, there is a change in the thermal expansion slope, with the rate of thermal expansion being lower for the solid material than for the supercooled liquid. This behavior is due to the absence of a long-range order in the molecular structure of noncrystalline materials, which prevents the abrupt volumetric change seen in crystalline materials.
# The provided context does not explicitly define "specific heat" as a material property. Therefore, based on the given context, I cannot provide a definition for specific heat.
# The provided context does not explicitly define thermal conductivity as a material property. Therefore, based on the given context, I cannot provide an answer to the query about thermal conductivity.
# The provided context does not contain a definition or explanation of thermal diffusivity.
# The important variables that affect mass diffusion are the number of nucleation sites in the molten material and the cooling rate of the mass.
# Resistivity is a material property that quantifies how strongly a material opposes the flow of electric current. It is an intrinsic property that depends on the material's composition and structure, and it is typically measured in ohm-meters (Ω·m). High resistivity indicates that the material is a poor conductor of electricity, while low resistivity indicates that the material is a good conductor.
# Metals are better conductors of electricity than ceramics and polymers because their atoms are held together by metallic bonding, which allows their valence electrons to move about with relative freedom. This free movement of electrons facilitates high electrical conductivity. In contrast, ceramics are characterized by ionic or covalent bonding, which results in strong attractive forces within the molecules and makes them electrically insulating. Polymers, held together by covalent bonding and secondary bonding (van der Waals forces), also exhibit high electrical resistivity, making them poor conductors of electricity.
#     LangChain
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        NaN
# 29        NaN
# 30        NaN
# 31        NaN
# 32        NaN
# 33        NaN
# 34        NaN
# 35        NaN
# 36        NaN
# 37        NaN
# 38        NaN
# 39        NaN
# 40        NaN
# 41        NaN
# 42        NaN
# 43        NaN
# 44        NaN

# %%
response = results[-45:]


response
# Out:
# ['The elements listed in the Periodic Table can be divided into three categories: metals, nonmetals, and metalloids (or semimetals). Examples of each category are:\n\n- Metals: Iron (Fe)\n- Nonmetals: Nitrogen (N)\n- Metalloids (or Semimetals): Silicon (Si)',
#  'Some materials that possess a noncrystalline structure include glass (e.g., window glass) and fused silica.',
#  'The noble metals are copper, silver, and gold.',
#  'Primary bonding involves strong atom-to-atom attractions that include the exchange or sharing of valence electrons, forming bonds such as ionic, covalent, and metallic. These bonds are generally associated with the formation of molecules and are much stronger than secondary bonds. In contrast, secondary bonding involves attraction forces between molecules (intermolecular forces) without the transfer or sharing of electrons, making these bonds weaker. Examples of secondary bonding include dipole forces, London forces, and hydrogen bonding.',
#  'Ionic bonding works by the transfer of electrons from atoms of one element to atoms of another element. Specifically, the atoms of one element give up their outer electron(s), which are then attracted to the atoms of another element to increase their electron count in the outermost shell to eight, achieving a stable atomic configuration. This transfer of electrons results in the formation of ions, which are atoms with a net electric charge due to the loss or gain of electrons. The electrostatic attraction between the positively charged ions (cations) and negatively charged ions (anions) forms a strong bond, known as an ionic bond. An example of ionic bonding is the formation of sodium fluoride (NaF) from sodium (Na) and fluorine (F), where sodium donates an electron to fluorine, resulting in the formation of Na+ and F- ions. Properties of materials with ionic bonding include low electrical conductivity and poor ductility.',
#  'Crystalline structures in materials are characterized by a highly ordered arrangement of atoms or molecules in a repeating pattern, forming a crystal lattice. This orderliness results in distinct unit cells, such as BCC (Body-Centered Cubic), FCC (Face-Centered Cubic), or HCP (Hexagonal Close-Packed) structures, which are typical in metals. Crystalline materials exhibit properties such as high strength, hardness, and, in the case of metals, ductility and high electrical and thermal conductivity.\n\nNoncrystalline (or amorphous) structures, on the other hand, lack this long-range order. The atoms or molecules are arranged more randomly, without a repeating pattern. This structure is common in materials like glass (a type of ceramic) and certain polymers. Noncrystalline materials tend to be less rigid and more brittle compared to their crystalline counterparts. They also exhibit different thermal and electrical properties, often being insulating and less thermally conductive.',
#  'Some common point defects in a crystal lattice structure include:\n\n1. Vacancy: A missing atom within the lattice structure.\n2. Ion-pair vacancy (Schottky defect): A missing pair of ions of opposite charge in a compound that maintains an overall charge balance.\n3. Interstitialcy: A lattice distortion produced by the presence of an extra atom in the structure.\n4. Displaced ion (Frenkel defect): Occurs when an ion is removed from its regular position in the lattice structure and inserted into an interstitial position not normally occupied by such an ion.',
#  'Elastic deformation in a crystal lattice structure involves a temporary tilting of the lattice without any permanent changes in the positions of the atoms. When the applied mechanical stress is removed, the lattice structure returns to its original shape. In contrast, plastic deformation results in a permanent shape change where the atoms in the lattice move from their previous locations to form a new equilibrium lattice. This permanent movement of atoms means that the lattice does not return to its original shape even after the stress is removed.',
#  'Grain boundaries contribute to the strain hardening phenomenon in metals by interrupting the continued movement of dislocations. This interference with dislocation movement increases the strength of the metal as it is deformed.',
#  'Some materials that have a crystalline structure include metals (which almost always exist as crystals in their solid state) and most ceramics. For example, silica occurs in nature as crystalline quartz.',
#  'Manufacturing is the process of producing hardware, which ranges from nuts and bolts to digital computers and military weapons. It involves the conversion of raw materials into finished products through various processes and technologies. Manufacturing is a critical commercial activity performed by companies that sell products to customers, and it is a principal activity in secondary industries. The term is derived from the Latin words "manus" (hand) and "factus" (make), originally meaning "made by hand," but today it encompasses automated and computer-controlled machinery.',
#  'The provided context does not explicitly define the difference between thermoplastic polymers and thermosetting polymers. However, based on general knowledge, the difference can be summarized as follows:\n\nThermoplastic polymers can be melted and reshaped multiple times without undergoing any significant chemical change. They become soft when heated and harden upon cooling. Examples include polyethylene and polyvinylchloride.\n\nThermosetting polymers, on the other hand, undergo a chemical change when they are first heated and molded, which makes them set into a permanent shape. Once set, they cannot be remelted or reshaped. Examples include Bakelite and epoxy resins.',
#  'A unit operation is defined as a single step in the sequence of steps required to make the final product. The cycle time of a unit operation is the time that one work unit spends being processed or assembled, which includes the time interval between when one work unit begins the operation and the next unit begins. It typically consists of the actual processing time plus the work handling time, and in some processes, it also includes the time required to periodically change the tooling used in the operation when it wears out.',
#  'In manufacturing processes, a processing operation uses energy to alter a work part’s shape, physical properties, or appearance to add value to the material. This involves applying mechanical, thermal, electrical, or chemical energy in a controlled way by means of machinery and tooling. On the other hand, an assembly operation involves putting together multiple components to create a final product. The context provided does not explicitly define assembly operations, but it focuses on processing operations which include shaping, property-enhancing, and surface processing operations.',
#  'The four categories of shaping operations are:\n\n1. **Solidification processes**: The starting material is a heated liquid or semifluid that cools and solidifies to form the part geometry.\n2. **Particulate processing**: The starting material is a powder, and the powders are formed and heated into the desired geometry.\n3. **Deformation processes**: The starting material is a ductile solid (commonly metal) that is deformed to shape the part.\n4. **Material removal processes**: The starting material is a solid (ductile or brittle), from which material is removed so that the resulting part has the desired geometry.',
#  'Net shape processes are manufacturing methods that transform nearly all of the starting material into the final product, requiring no subsequent machining to achieve the final part geometry. In contrast, near net shape processes are those that require minimal machining to produce the final shape.',
#  'The four types of permanent joining processes used in assembly are welding, brazing, soldering, and adhesive bonding.',
#  'A machine tool is a type of production equipment used to make parts for consumer products and components for other production machines. It is considered the mother of all machinery in both a historic and reproductive sense.',
#  'Special purpose production equipment is designed to produce a specific part or product in very large quantities. It is typically used for mass production, where the economics justify large investments to achieve high efficiencies and short cycle times. This equipment is often unique to the process and may not be commercially available, leading some companies to develop their own special purpose equipment. The tooling for special purpose machines is often an integral part of the machine and may not need changing except for replacement or repair.\n\nGeneral purpose production equipment, on the other hand, is more flexible and adaptable to a variety of jobs. It is commercially available for any manufacturing company to invest in. The tooling used with general purpose equipment is designed to be exchanged for different work part types, allowing the equipment to be used for various production runs.',
#  'Batch production is a manufacturing approach where a batch of one product is made, after which the manufacturing equipment is changed over to produce a batch of the next product, and so on. This method is often used for medium-quantity production (100–10,000 units annually) because the production rate of the equipment is greater than the demand rate for any single product type. This allows the same equipment to be shared among multiple products. However, the changeover between production runs takes time, which is a disadvantage as this setup time is lost production time. Batch production is commonly used for make-to-stock situations, where items are manufactured to replenish inventory that has been gradually depleted by demand. The equipment in batch production is usually arranged in a process layout.',
#  'A process layout and a product layout differ primarily in how equipment and workstations are arranged and how work units move through the production facility:\n\n1. **Process Layout**:\n   - **Arrangement**: Equipment is arranged according to function or type. For example, lathes are in one department, milling machines in another, and so on.\n   - **Flexibility**: Noted for its flexibility, it can accommodate a variety of operation sequences for different part configurations.\n   - **Operation Sequence**: Different parts, each requiring a different operation sequence, are routed through the departments in the particular order needed for their processing, usually in batches.\n   - **Efficiency**: The machinery and methods to produce a part are not designed for high efficiency.\n\n2. **Product Layout**:\n   - **Arrangement**: Workstations and equipment are arranged in sequence, typically into one long line or a series of connected line segments.\n   - **Efficiency**: Designed specifically for the product to maximize efficiency.\n   - **Operation Sequence**: The work units are physically moved through the sequence to complete the product, often using mechanized conveyors.\n   - **Example**: The most familiar example is the assembly line, where each station completes a small amount of the total work on each unit of product.\n\nIn summary, a process layout is organized by function and is flexible but less efficient, while a product layout is organized by the sequence of operations for a specific product and is highly efficient.',
#  'Primary, secondary, and tertiary industries differ in their roles and the types of activities they perform:\n\n1. **Primary Industries**: These industries cultivate and exploit natural resources. Examples include agriculture, forestry, fishing, livestock, quarries, and mining.\n\n2. **Secondary Industries**: These industries take the outputs of the primary industries and convert them into consumer and capital goods. Manufacturing is the principal activity in this category. Examples include aerospace, food processing, apparel, glass and ceramics, automotive, heavy machinery, basic metals, paper, beverages, petroleum refining, building materials, pharmaceuticals, chemicals, plastics (shaping), computers, power utilities, construction, publishing, consumer appliances, textiles, electronics, tire and rubber, equipment, wood and furniture, and fabricated metals.\n\n3. **Tertiary Industries**: These industries constitute the service sector of the economy. Examples include banking, insurance, communications, legal services, education, real estate, entertainment, repair and maintenance, government, restaurants, health and medical services, retail trade, hotels, tourism, information services, transportation, and wholesale trade.',
#  'Two departments that are typically classified as manufacturing support departments are:\n\n1. Quality control systems\n2. Manufacturing support systems',
#  'Overhead costs in a manufacturing company consist of all the expenses of operating the company other than material, labor, and equipment. They can be divided into two categories:\n\n1. **Factory Overhead**: This includes the costs of running the factory excluding materials, direct labor, and equipment. Examples of factory overhead costs are:\n   - Plant supervision\n   - Maintenance\n   - Insurance\n   - Heat and light\n\n2. **Corporate Overhead**: These are company expenses not directly related to the factory. Examples of corporate overhead costs are:\n   - Sales\n   - Marketing\n   - Accounting\n   - Legal\n   - Engineering\n   - Research and development\n   - Office space\n   - Utilities\n   - Health benefits\n\nThese overhead costs are necessary for the company’s operations but are not directly tied to the manufacturing process. For pricing the product, these costs must be included to ensure the company does not lose money on each product sold.',
#  'The two categories of overhead costs in a manufacturing company are:\n\n1. **Factory Overhead**: This consists of the costs of running the factory excluding materials, direct labor, and equipment. It includes expenses such as plant supervision, maintenance, insurance, heat, and light.\n\n2. **Corporate Overhead**: This consists of company expenses not related to the factory, such as sales, marketing, accounting, legal, engineering, research and development, office space, utilities, and health benefits. These functions are required in the company but are not directly related to the cost of manufacturing.',
#  "Fixed costs, such as the cost of production equipment, remain constant regardless of the level of production output. They are capital investments made with the expectation that they will generate a revenue stream that exceeds their cost over time. These costs are paid upfront and amortized over the equipment's lifetime.\n\nVariable costs, on the other hand, fluctuate with the level of production. They include direct labor and material costs, which are incurred as they are used. Direct labor cost is measured per time unit (e.g., $/min), and material cost is measured per piece (e.g., $/pc).",
#  'The term "availability" is not explicitly defined in the provided context. However, based on the context, it can be inferred that "availability" refers to the available labor hours of productive capacity in a machine shop that produces a variety of parts. This implies the measure of how much productive capacity is accessible or usable within a given time period.',
#  'Consumer goods are products purchased directly by consumers for personal use, such as cars, personal computers, TVs, tires, and tennis rackets. Capital goods, on the other hand, are purchased by companies to produce goods and/or provide services. Examples of capital goods include aircraft, computers, communication equipment, medical apparatus, trucks and buses, railroad locomotives, machine tools, and construction equipment.',
#  'Soft product variety occurs when there are only small differences among products, such as the differences among car models made on the same production line. In an assembled product, soft variety is characterized by a high proportion of common parts among the models. Hard product variety occurs when the products differ substantially, and there are few common parts, if any. The difference between a car and a truck exemplifies hard variety.',
#  'There is an inverse correlation between product variety and production quantity in terms of factory operations. If a factory’s product variety is high, then its production quantity is likely to be low; but if production quantity is high, then product variety will be low.',
#  'Technological processing capability refers to the available set of manufacturing processes that a plant or company can perform. It includes not only the physical processes but also the expertise possessed by plant personnel in these processing technologies. This capability is closely related to the material types that the processes can handle, meaning that by specializing in certain processes, a plant simultaneously specializes in certain material types. Companies must focus on designing and manufacturing products that are compatible with their technological processing capability.',
#  'The four categories of engineering materials used in manufacturing are:\n\n1. Metals\n2. Ceramics\n3. Polymers\n4. Composites',
#  'Steel can be defined as an iron–carbon alloy containing 0.02% to 2.11% carbon.',
#  'Applications of steel include construction (bridges, I-beams, and nails), transportation (trucks, rails, and rolling stock for railroads), and consumer products (automobiles and appliances).',
#  'Density, as a material property, refers to the mass per unit volume of a material. It is an important characteristic that can influence various mechanical properties and behaviors of materials. For example, in the context of crystalline and noncrystalline materials, density can change with the state of the material (solid or liquid) and its atomic arrangement. Crystalline materials typically have a denser, more closely packed structure compared to noncrystalline materials, which have a more loosely packed and random arrangement of atoms.',
#  'The provided context does not define or mention dielectric strength as a material property.',
#  'The provided context does not contain information about what an electrolyte is.',
#  'The provided context does not explicitly discuss the melting characteristics of metal alloys. It primarily focuses on the melting characteristics of pure metals and amorphous materials. Therefore, based on the given context, the difference in melting characteristics between a pure metal element and a metal alloy cannot be determined.',
#  'The melting characteristics of a noncrystalline material such as glass differ significantly from those of a pure metal. When glass transitions from the solid to the liquid state, it does not exhibit the sudden volumetric change characteristic of crystalline materials. Instead, as glass cools from a high-temperature liquid state, it gradually transforms into a solid through a transition phase called a supercooled liquid. During this phase, the material becomes increasingly viscous as the temperature decreases. Glass passes through its melting temperature \\( T_m \\) without a change in its thermal expansion slope. Eventually, a point is reached where the supercooled liquid converts to a solid, known as the glass-transition temperature \\( T_g \\). At this point, there is a change in the thermal expansion slope, with the rate of thermal expansion being lower for the solid material than for the supercooled liquid. This behavior is due to the absence of a long-range order in the molecular structure of noncrystalline materials, which prevents the abrupt volumetric change seen in crystalline materials.',
#  'The provided context does not explicitly define "specific heat" as a material property. Therefore, based on the given context, I cannot provide a definition for specific heat.',
#  'The provided context does not explicitly define thermal conductivity as a material property. Therefore, based on the given context, I cannot provide an answer to the query about thermal conductivity.',
#  'The provided context does not contain a definition or explanation of thermal diffusivity.',
#  'The important variables that affect mass diffusion are the number of nucleation sites in the molten material and the cooling rate of the mass.',
#  "Resistivity is a material property that quantifies how strongly a material opposes the flow of electric current. It is an intrinsic property that depends on the material's composition and structure, and it is typically measured in ohm-meters (Ω·m). High resistivity indicates that the material is a poor conductor of electricity, while low resistivity indicates that the material is a good conductor.",
#  'Metals are better conductors of electricity than ceramics and polymers because their atoms are held together by metallic bonding, which allows their valence electrons to move about with relative freedom. This free movement of electrons facilitates high electrical conductivity. In contrast, ceramics are characterized by ionic or covalent bonding, which results in strong attractive forces within the molecules and makes them electrically insulating. Polymers, held together by covalent bonding and secondary bonding (van der Waals forces), also exhibit high electrical resistivity, making them poor conductors of electricity.']

# %%
Outputs_df = pd.DataFrame(response, columns=['LlamaIndex'])
Outputs_df
# Out:
#                                            LlamaIndex
# 0   The elements listed in the Periodic Table can ...
# 1   Some materials that possess a noncrystalline s...
# 2      The noble metals are copper, silver, and gold.
# 3   Primary bonding involves strong atom-to-atom a...
# 4   Ionic bonding works by the transfer of electro...
# 5   Crystalline structures in materials are charac...
# 6   Some common point defects in a crystal lattice...
# 7   Elastic deformation in a crystal lattice struc...
# 8   Grain boundaries contribute to the strain hard...
# 9   Some materials that have a crystalline structu...
# 10  Manufacturing is the process of producing hard...
# 11  The provided context does not explicitly defin...
# 12  A unit operation is defined as a single step i...
# 13  In manufacturing processes, a processing opera...
# 14  The four categories of shaping operations are:...
# 15  Net shape processes are manufacturing methods ...
# 16  The four types of permanent joining processes ...
# 17  A machine tool is a type of production equipme...
# 18  Special purpose production equipment is design...
# 19  Batch production is a manufacturing approach w...
# 20  A process layout and a product layout differ p...
# 21  Primary, secondary, and tertiary industries di...
# 22  Two departments that are typically classified ...
# 23  Overhead costs in a manufacturing company cons...
# 24  The two categories of overhead costs in a manu...
# 25  Fixed costs, such as the cost of production eq...
# 26  The term "availability" is not explicitly defi...
# 27  Consumer goods are products purchased directly...
# 28  Soft product variety occurs when there are onl...
# 29  There is an inverse correlation between produc...
# 30  Technological processing capability refers to ...
# 31  The four categories of engineering materials u...
# 32  Steel can be defined as an iron–carbon alloy c...
# 33  Applications of steel include construction (br...
# 34  Density, as a material property, refers to the...
# 35  The provided context does not define or mentio...
# 36  The provided context does not contain informat...
# 37  The provided context does not explicitly discu...
# 38  The melting characteristics of a noncrystallin...
# 39  The provided context does not explicitly defin...
# 40  The provided context does not explicitly defin...
# 41  The provided context does not contain a defini...
# 42  The important variables that affect mass diffu...
# 43  Resistivity is a material property that quanti...
# 44  Metals are better conductors of electricity th...

# %%
df = pd.concat([df, Outputs_df], axis=1)
df
# Out:
#                                              Question  \
# 0   The elements listed in the Periodic Table can ...
# 1   Identify some materials that possess a noncrys...
# 2                Which elements are the noble metals?
# 3   What is the difference between primary and sec...
# 4                   Describe how ionic bonding works?
# 5   What is the difference between crystalline and...
# 6   What are some common point defects in a crysta...
# 7   Define the difference between elastic and plas...
# 8   How do grain boundaries contribute to the stra...
# 9   Identify some materials that have a crystallin...
# 10                              Define manufacturing.
# 11  What is the difference between a thermoplastic...
# 12  Manufacturing processes are usually accomplish...
# 13  In manufacturing processes, what is the differ...
# 14  One of the three general types of processing o...
# 15  What is the difference between net shape proce...
# 16  Identify the four types of permanent joining p...
# 17                            What is a machine tool?
# 18  What is the difference between special purpose...
# 19  Define batch production and describe why it is...
# 20  What is the difference between a process layou...
# 21  What are the differences between primary, seco...
# 22  Name two departments that are typically classi...
# 23  What are overhead costs in a manufacturing com...
# 24  Name and define the two categories of overhead...
# 25  What is the difference between fixed costs and...
# 26            What is meant by the term availability?
# 27  What is the difference between consumer goods ...
# 28  What is the difference between soft product va...
# 29  How are product variety and production quantit...
# 30  One of the dimensions of manufacturing capabil...
# 31  What are the four categories of engineering ma...
# 32                   What is the definition of steel?
# 33  What are some of the typical applications of s...
# 34             Define density as a material property.
# 35  What is dielectric strength as a material prop...
# 36                            What is an electrolyte?
# 37  What is the difference in melting characterist...
# 38  Describe the melting characteristics of a nonc...
# 39       Define specific heat as a material property.
# 40  What is thermal conductivity as a material pro...
# 41                        Define thermal diffusivity.
# 42  What are the important variables that affect m...
# 43         Define resistivity as a material property.
# 44  Why are metals better conductors of electricit...
#
#                                                Answer  \
# 0   Answer. The three categrories of elements are ...
# 1   Answer. Materials typically having a noncrysta...
# 2   Answer. The noble metals are copper, silver, a...
# 3   Answer. Primary bonding is strong bonding betw...
# 4   Answer. In ionic bonding, atoms of one element...
# 5   Answer. The atoms in a crystalline structure a...
# 6   Answer. The common point defects are (1) vacan...
# 7   Answer. Elastic deformation involves a tempora...
# 8   Answer. Grain boundaries block the continued m...
# 9   Answer. Materials typically possessing a cryst...
# 10  Answer. The text defines manufacturing in two ...
# 11  Answer. Thermoplastic polymers can be subjecte...
# 12  Answer. A unit operation is a single step in t...
# 13  Answer. A processing operation transforms a wo...
# 14  Answer. The four categories of shaping operati...
# 15  Answer. Net shape processes are manufacturing ...
# 16  Answer. The four types are welding, brazing, s...
# 17  Answer. The term developed during the Industri...
# 18  Answer. General-purpose equipment is more flex...
# 19  Answer. Batch production is where groups, lots...
# 20  Answer. A process layout is one where the mach...
# 21  Answer. A primary industry is one that cultiva...
# 22  Answer. A common organizational structure incl...
# 23  Answer. Overhead costs consist of all of the e...
# 24  Answer. The two categories are (1) factory ove...
# 25  Answer. A fixed cost remains constant for any ...
# 26  Answer. Availability is a reliability term whi...
# 27  Answer. Consumer goods are products purchased ...
# 28  Answer. Soft product variety is when there are...
# 29  Answer. In general, production quantity is inv...
# 30  Answer. The technological processing capabilit...
# 31  Answer. The four categories of engineering mat...
# 32  Answer. Steel can be defined as an ironÐcarbon...
# 33  Answer. Applications of steel include construc...
# 34  Answer. Density is the weight per unit volume ...
# 35  Answer. Dielectric strength is defined as the ...
# 36  Answer. An electrolyte is an ionized solution ...
# 37  Answer. A pure metal element melts at one temp...
# 38  Answer. In the heating of a noncrystalline mat...
# 39  Answer. Specific heat is defined as the quanti...
# 40  Answer. Thermal conductivity is the capacity o...
# 41  Answer. Thermal diffusivity is thermal conduct...
# 42  Answer. According to Fick's first law, mass di...
# 43  Answer. Resistivity is the material's capacity...
# 44  Answer. Metals are better conductors because o...
#
#                                              GraphRag  \
# 0   The elements in the Periodic Table can be divi...
# 1   ### Noncrystalline Materials\n\nNoncrystalline...
# 2   ### Noble Metals\n\nNoble metals are a group o...
# 3   ### Differences Between Primary and Secondary ...
# 4   ### Understanding Ionic Bonding\n\nIonic bondi...
# 5   ### Differences Between Crystalline and Noncry...
# 6   ### Common Point Defects in a Crystal Lattice ...
# 7   ### Elastic Deformation\n\nElastic deformation...
# 8   ### Introduction\n\nGrain boundaries play a cr...
# 9   ### Crystalline Structures in Engineering Mate...
# 10  ### Definition of Manufacturing\n\nManufacturi...
# 11  ### Difference Between Thermoplastic and Therm...
# 12  I am sorry but I am unable to answer this ques...
# 13  ### Understanding Processing and Assembly Oper...
# 14  ### Categories of Shaping Operations\n\nShapin...
# 15  I am sorry but I am unable to answer this ques...
# 16  ### Permanent Joining Processes in Assembly\n\...
# 17  ### Understanding Machine Tools\n\nMachine too...
# 18  ### Differences Between Special Purpose and Ge...
# 19  ### Definition of Batch Production\n\nBatch pr...
# 20  ### Differences Between Process Layout and Pro...
# 21  ### Differences Between Primary, Secondary, an...
# 22  ### Manufacturing Support Departments\n\nTwo d...
# 23  ### Overview of Overhead Costs in a Manufactur...
# 24  In a manufacturing company, overhead costs are...
# 25  ### Understanding Fixed and Variable Costs\n\n...
# 26  ### Understanding Availability\n\nThe term 'av...
# 27  ### Difference Between Consumer Goods and Capi...
# 28  ### Understanding Soft and Hard Product Variet...
# 29  ### Relationship Between Product Variety and P...
# 30  ### Definition of Technological Processing Cap...
# 31  ### Categories of Engineering Materials\n\nThe...
# 32  ### Definition of Steel\n\nSteel is a crucial ...
# 33  ### Typical Applications of Steel\n\nSteel is ...
# 34  ### Definition of Density\n\nDensity is a fund...
# 35  I am sorry but I am unable to answer this ques...
# 36  I am sorry but I am unable to answer this ques...
# 37  ### Melting Characteristics of Pure Metal Elem...
# 38  ### Melting Characteristics of Noncrystalline ...
# 39  ### Understanding Specific Heat as a Material ...
# 40  ### Understanding Thermal Conductivity\n\nTher...
# 41  I am sorry but I am unable to answer this ques...
# 42  I am sorry but I am unable to answer this ques...
# 43  I am sorry but I am unable to answer this ques...
# 44  ### Electrical Conductivity in Metals\n\nMetal...
#
#                                             LangChain  \
# 0   The elements listed in the Periodic Table can ...
# 1   Some materials that possess a noncrystalline s...
# 2      The noble metals are copper, silver, and gold.
# 3   Primary bonding involves strong atom-to-atom a...
# 4   Ionic bonding involves the transfer of outer e...
# 5   The difference between crystalline and noncrys...
# 6   Some common point defects in a crystal lattice...
# 7   Elastic deformation involves a temporary tilti...
# 8   Grain boundaries contribute to the strain hard...
# 9   Some materials that have a crystalline structu...
# 10  Manufacturing can be defined in two ways: one ...
# 11  The difference between a thermoplastic polymer...
# 12  A unit operation is a single step in the seque...
# 13  In manufacturing processes, the difference bet...
# 14  The four categories of shaping operations are:...
# 15  Net shape processes are manufacturing processe...
# 16  The four types of permanent joining processes ...
# 17  A machine tool is a power-driven machine used ...
# 18  Special purpose production equipment is design...
# 19  Batch production is a manufacturing approach w...
# 20  A process layout and a product layout differ p...
# 21  The differences between primary, secondary, an...
# 22  Two departments that are typically classified ...
# 23  Overhead costs in a manufacturing company cons...
# 24  The two categories of overhead costs in a manu...
# 25  Fixed costs are expenses that remain constant ...
# 26  The term availability, denoted by the symbol A...
# 27  Consumer goods are products purchased directly...
# 28  Soft product variety refers to situations wher...
# 29  In typical factories, product variety and prod...
# 30  Technological processing capability is the ava...
# 31  The four categories of engineering materials u...
# 32  Steel is defined as an iron–carbon alloy conta...
# 33  Typical applications of steel include construc...
# 34  Density, as a material property, is defined as...
# 35  The provided context does not contain informat...
# 36  The provided context does not explicitly defin...
# 37  The provided context does not give specific de...
# 38  The melting characteristics of a noncrystallin...
# 39  The provided context does not contain a defini...
# 40  The provided context does not explicitly defin...
# 41  The provided context does not contain a defini...
# 42  The provided context does not explicitly menti...
# 43  The provided context does not define resistivi...
# 44  Metals are better conductors of electricity th...
#
#                                            LlamaIndex
# 0   The elements listed in the Periodic Table can ...
# 1   Some materials that possess a noncrystalline s...
# 2      The noble metals are copper, silver, and gold.
# 3   Primary bonding involves strong atom-to-atom a...
# 4   Ionic bonding works by the transfer of electro...
# 5   Crystalline structures in materials are charac...
# 6   Some common point defects in a crystal lattice...
# 7   Elastic deformation in a crystal lattice struc...
# 8   Grain boundaries contribute to the strain hard...
# 9   Some materials that have a crystalline structu...
# 10  Manufacturing is the process of producing hard...
# 11  The provided context does not explicitly defin...
# 12  A unit operation is defined as a single step i...
# 13  In manufacturing processes, a processing opera...
# 14  The four categories of shaping operations are:...
# 15  Net shape processes are manufacturing methods ...
# 16  The four types of permanent joining processes ...
# 17  A machine tool is a type of production equipme...
# 18  Special purpose production equipment is design...
# 19  Batch production is a manufacturing approach w...
# 20  A process layout and a product layout differ p...
# 21  Primary, secondary, and tertiary industries di...
# 22  Two departments that are typically classified ...
# 23  Overhead costs in a manufacturing company cons...
# 24  The two categories of overhead costs in a manu...
# 25  Fixed costs, such as the cost of production eq...
# 26  The term "availability" is not explicitly defi...
# 27  Consumer goods are products purchased directly...
# 28  Soft product variety occurs when there are onl...
# 29  There is an inverse correlation between produc...
# 30  Technological processing capability refers to ...
# 31  The four categories of engineering materials u...
# 32  Steel can be defined as an iron–carbon alloy c...
# 33  Applications of steel include construction (br...
# 34  Density, as a material property, refers to the...
# 35  The provided context does not define or mentio...
# 36  The provided context does not contain informat...
# 37  The provided context does not explicitly discu...
# 38  The melting characteristics of a noncrystallin...
# 39  The provided context does not explicitly defin...
# 40  The provided context does not explicitly defin...
# 41  The provided context does not contain a defini...
# 42  The important variables that affect mass diffu...
# 43  Resistivity is a material property that quanti...
# 44  Metals are better conductors of electricity th...

# %%
df.to_csv(csv_file_path, index=False)
